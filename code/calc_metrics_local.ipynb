# %%
from rdflib import Graph
from rdflib import RDF
from rdflib import URIRef
from rdflib import Literal
import networkx as nx
import matplotlib.pyplot as plt
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from queries import QUERY_AI, QUERY_FILM, QUERY_PERSON
from paths_to_examples import REPO_BOOKS, REPO_PEOPLE, WIKIDATA, GPT_EX, GPT_EX2, GPT_SUBCLASSES, EP_DG_1_TTL, EP_DG_1_JSON

DEBUG = True  # for debug prints
PRINTGRAPH = False # for showing the networkX graph
LOCAL = True # for choosing local ttl file path or SPARQL endpoint 
DEC_PLACES = 2 # for rounding float values to x decimal places

def debug_print(*args, **kwargs):
    if DEBUG:
        print(*args, **kwargs)


# printing all elements of a set
def print_set(set):
    if DEBUG:
        for i in set:
            print(str(i))

def show_graph(G):
    if PRINTGRAPH:
        # calculating positions for nodes
        pos = nx.spring_layout(G, k=0.5, iterations=50)

        # printing nodes and edges
        plt.figure(figsize=(12, 8))
        nx.draw(G, pos, with_labels=True, node_color="lightblue", node_size=1500, font_size=10, font_weight="bold", arrows=True)

        # printing labels for the edges
        edge_labels = nx.get_edge_attributes(G, 'label')
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

        plt.title("RDF Graph")
        plt.axis("off")
        plt.show()

        print("FINISHED PRINTING GRAPH\n\n")        

# Calculating all paths from one root node (start node)
def find_all_paths(G, start_node):
    # helper function for DFS
    def dfs(node, path):
        global num_paths
        global abs_depth
        global max_depth

        # skip node if it already is in path (avoiding cycles)
        if node in path:
            return
        
        # add current node to path
        path.append(node)
        
        neighbors = list(G.neighbors(node))
        # if node does not have any neighbors left, there is no other path left
        if not neighbors:
            paths.append(list(path))  # Store current path
            num_paths += 1
            abs_depth += (len(path) - 1) # cardinality of a path = number of EDGES in path (=> -1)
            if (len(path)-1) > max_depth:
                max_depth = len(path) - 1
        
        # recursively extend the path for each neighbor
        for neighbor in neighbors:
            dfs(neighbor, path)
        
        # remove node from the path to find next path
        path.pop()

    # list which stores all paths
    paths = []
    
    # starts DFS with start_node
    dfs(start_node, [])
    
    return paths

# %%
# path to ttl file
# can also be an online graph source
ttl_file_path = EP_DG_1_TTL
g = Graph()

print("STARTING PARSING")

# if it fails -> print some error
try:
    # TODO: He said you can just drop the format parameter, then it automatically recognizes the format
    g.parse(ttl_file_path)
except Exception as e:
    print(f"ERROR WHILE PARSING GRAPH: {e}")    

print("Number of triples: " + str(len(g)))    
print("FINISHED PARSING\n")

#for s, p, o in g:
 #   print(s, p, o)

print("STARTING GETTING ROOT NODES AND LITERALS")

all_nodes = set(g.subjects())

# printing all subject nodes
# print_set(nodes)

# all objects
object_nodes = set(g.objects())

# all literals in a graph (literals can only appear as objects)
literals = set(o for o in object_nodes if isinstance(o, Literal))

# converting items of literals to strings
literals = {str(item) for item in literals}

# getting possible root nodes
root_nodes = all_nodes - object_nodes

debug_print("Root Nodes:")
print_set(root_nodes)
#debug_print("\n")

print("FINISHED GETTING ROOT NODES AND LITERALS\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # path to ttl file
#       2 # can also be an online graph source
# ----> 3 ttl_file_path = EP_DG_1_TTL
#       4 g = Graph()
#       6 print("STARTING PARSING")
#
# NameError: name 'EP_DG_1_TTL' is not defined

# %%
import sys
# path to ttl file
# can also be an online graph source
ttl_file_path = EP_DG_1_TTL
g = Graph()

print("STARTING PARSING")

# if it fails -> print some error
try:
    # TODO: He said you can just drop the format parameter, then it automatically recognizes the format
    g.parse(ttl_file_path)
except Exception as e:
    print("ERROR WHILE PARSING GRAPH: {e}")    

print("Number of triples: " + str(len(g)))    
print("FINISHED PARSING\n")

#for s, p, o in g:
 #   print(s, p, o)

print("STARTING GETTING ROOT NODES AND LITERALS")

all_nodes = set(g.subjects())

# printing all subject nodes
# print_set(nodes)

# all objects
object_nodes = set(g.objects())

# all literals in a graph (literals can only appear as objects)
literals = set(o for o in object_nodes if isinstance(o, Literal))

for lit in literals:
    datatype = lit.datatype
    lang = lit.language
    print(str(lit) + "-" + str(datatype) + "-" + str(lang))

# converting items of literals to strings
literals = {str(item) for item in literals}


# getting possible root nodes
root_nodes = all_nodes - object_nodes

debug_print("Root Nodes:")
print_set(root_nodes)
#debug_print("\n")

print("FINISHED GETTING ROOT NODES AND LITERALS\n")

print("STARTING CREATING GRAPH G")

# NetworkX-DiGraph for visualization
G = nx.DiGraph()

debug_print("Printing all triples:")
# add triples to Graph G
for subj, pred, obj in g:
    if isinstance(obj, Literal):
        G.add_edge(str(subj), str(obj) + "_" + str(obj.datatype) + "_" + str(obj.language), label=str(pred))
        #debug_print("(" , str(subj), ",", str(pred), ",",  str(obj) + "_" + str(obj.datatype) + "_" + str(obj.language), ")")
    else:
        G.add_edge(str(subj), str(obj), label=str(pred))
    #debug_print("(" , str(subj), ",", str(pred), ",", str(obj), ")")
    
    debug_print("(" , str(subj), ",", str(pred), ",", str(obj), ")")

print("FINISHED CREATING GRAPH G\n")

show_graph(G)

num_paths = 0
abs_depth = 0
max_depth = 0

print("STARTING CALCULATING PATHS")

# list of paths for all root nodes
all_paths = {}

# calculating all paths from root nodes
for root in list(root_nodes):
    str_root = str(root)
    debug_print("Starting searching for paths with root node: " + str_root)
    all_paths[str_root] = find_all_paths(G, str_root)

print("FINISHED CALCULATING PATHS\n")

#sys.exit()

# Output root node + found paths
# print("FOUND PATHS:")
# for root_node, paths in all_paths.items():
#     print(f"Root-Knoten: {root_node}")
#     for path in paths:
#         print(path)

# Output found paths
print("FOUND PATHS:")
for root_node, paths in all_paths.items():
    for path in paths:
        print(path)
        print("Path length = " + str(len(path)-1))
        

#num_paths = len(all_paths)

print("RESULTS:")

print("-Number of Paths: " + str(num_paths))
print("-Absolute depth: " + str(abs_depth))

avg_depth = abs_depth / num_paths

print("-Average depth: " + str(avg_depth))
print("-Maximal depth: " + str(max_depth))
# Out:
# STARTING PARSING
# Number of triples: 179
# FINISHED PARSING
#
# STARTING GETTING ROOT NODES AND LITERALS
# Bebauungsplan-None-de
# Υπηρεσία έμπνευσης για το σχέδιο ανάπτυξης της υπηρεσίας XPlanning για τις γραμμές κατασκευής σχεδίου Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-el-t-de-t0-mtec
# download-None-nl-t-en-t0-mtec
# Služba INSPIRE za storitev razvojnega načrta (XPlanGML 5.0.1) za projektne linije Rindelbach Rattstadt Am Ortsweg št. 5 mesta Ellwangen (Jagst) (INSPIRE GML)-None-sl-t-de-t0-mtec
# Siehe referenzierte Spezifikation-None-de
# Služba Inspirace pro plán rozvoje (XPlanGML 5.0.1) pro plánovací linky Rindelbach Rattstadt Am Ortsweg č. 5 města Ellwangen (Jagst) (INSPIRE GML)-None-cs-t-de-t0-mtec
# 2023-02-25-http://www.w3.org/2001/XMLSchema#date-None
# Descarcă-None-ro-t-en-t0-mtec
# Bebauungspläne-None-de
# Inspire Service for the Development Plan Service (XPlanGML 5.0.1) για τις γραμμές κατασκευής σχεδίων Rindelbach Rattstadt Am Ortsweg No. 5 της πόλης Ellwangen (Jagst) (INSPIRE GML)-None-el-t-de-t0-mtec
# prenos-None-sl-t-en-t0-mtec
# "download"@en-None-None
# infraLocal-None-de
# Stadt Ellwangen (Jagst)-None-None
# Service Inspire pour le plan de construction Service (XPlanGML 5.0.1) pour le plan Lignes de construction Rindelbach Rattstadt Am Ortsweg no 5 de la ville d’Ellwangen (Jagst) (INSPIRE GML)-None-fr-t-de-t0-mtec
# letöltés-None-hu-t-en-t0-mtec
# lataa-None-fi-t-en-t0-mtec
# VERORDNUNG (EG) Nr. 976/2009 DER KOMMISSION vom 19. Oktober 2009 zur Durchführung der Richtlinie 2007/2/EG des Europäischen Parlaments und des Rates hinsichtlich der Netzdienste-None-de
# allalaadimine-None-et-t-en-t0-mtec
# Servicio de inspiración para el Servicio del Plan de Desarrollo (XPlanGML 5.0.1) para las líneas de construcción del Plan Rindelbach Rattstadt Am Ortsweg N.º 5 de la ciudad de Ellwangen (Jagst) (INSPIRE GML)-None-es-t-de-t0-mtec
# Inspiration Service for the Development Plan Plan Service (XPlanGML 5.0.1) Suunnitelmalinjat Rindelbach Rattstadt Am Ortsweg No. 5 Ellwangen (Jagst) (INSPIRE GML)-None-fi-t-de-t0-mtec
# inspireidentifiziert-None-de
# descargar-None-es-t-en-t0-mtec
# POLYGON((10.17145992406387 48.974835601138444,10.173266397790224 48.974835601138444,10.173266397790224 48.97286574139233,10.17145992406387 48.97286574139233,10.17145992406387 48.974835601138444))-http://replacement.io/ont/geosparql#wktLiteral-None
# download-None-da-t-en-t0-mtec
# Inspirationsservice til udviklingsplanen XPlanning service til Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-da-t-de-t0-mtec
# Inspire Service for the Development Plan Service (XPlanGML 5.0.1) за Plan Building Lines Rindelbach Rattstadt Am Ortsweg № 5 на град Ellwangen (Jagst) (INSPIRE GML)-None-bg-t-de-t0-mtec
# изтегли-None-bg-t-en-t0-mtec
# 2024-02-24T16:23:06+00:00-http://www.w3.org/2001/XMLSchema#dateTime-None
# Baden-Württemberg-None-None
# 2024-09-23T04:54:37+00:00-http://www.w3.org/2001/XMLSchema#dateTime-None
# 2024-06-15T16:46:47+00:00-http://www.w3.org/2001/XMLSchema#dateTime-None
# Seirbhís inspioráide don phlean forbartha XPlanning seirbhíse do Phlean Tógála Línte Rindelbach Rattstadt Am Ortsweg Uimh. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-ga-t-de-t0-mtec
# Inspire Service for the Development Plan Service (XPlanGML 5.0.1) voor de Plan Building Lines Rindelbach Rattstadt Am Ortsweg nr. 5 van de stad Ellwangen (Jagst) (INSPIRE GML)-None-nl-t-de-t0-mtec
# Inspire pakalpojums attīstības plāna pakalpojumam (XPlanGML 5.0.1) Elvangenas pilsētas (Jagst) 5. plāna būvei Rindelbach Rattstadt Am Ortsweg (Jagst) (INSPIRE GML)-None-lv-t-de-t0-mtec
# 2009-10-20-http://www.w3.org/2001/XMLSchema#date-None
# Serviciul Inspirație pentru Planul de Dezvoltare (XPlanGML 5.0.1) pentru liniile de construcție a planului Rindelbach Rattstadt Am Ortsweg nr. 5 din orașul Ellwangen (Jagst) (INSPIRE GML)-None-ro-t-de-t0-mtec
# Služba za razvojni plan (XPlanGML 5.0.1) za plan izgradnje linija Rindelbach Rattstadt Am Ortsweg br. 5 grada Ellwangena (Jagst) (INSPIRE GML)-None-hr-t-de-t0-mtec
# Service Inspire pour le plan d’aménagement XPlan pour le plan Lignes de construction Rindelbach Rattstadt Am Ortsweg no 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-fr-t-de-t0-mtec
# 0800af55-8e56-49a0-8986-aa55151d0440-None-None
# Inspiráló szolgáltatás a Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) fejlesztési tervének XPlanning szolgáltatásához-None-hu-t-de-t0-mtec
# Servizz ta’ ispirazzjoni għas-servizz tal-pjan ta’ żvilupp XPlanning għall-Linji ta’ Kostruzzjoni tal-Pjan Rindelbach Rattstadt Am Ortsweg Nru 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-mt-t-de-t0-mtec
# Ellwangen-None-None
# Inspirationstjänst för utvecklingsplanen XPlanning för Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-sv-t-de-t0-mtec
# Inspire Service for the Development Plan Service (XPlanGML 5.0.1) for the Plan Building Lines Rindelbach Rattstadt Am Ortsweg No. 5 of the city of Ellwangen (Jagst) (INSPIRE GML)-None-en-t-de-t0-mtec
# PlannedLandUse-None-de
# Servizio Ispirare per il Piano di Sviluppo Servizio (XPlanGML 5.0.1) per la Plan Building Lines Rindelbach Rattstadt Am Ortsweg No. 5 della città di Ellwangen (Jagst) (INSPIRE GML)-None-it-t-de-t0-mtec
# lejupielādēt-None-lv-t-en-t0-mtec
# preuzimanje-None-hr-t-en-t0-mtec
# WFS-None-en
# 4c30b434751d57dd0212dc3433813e61-None-None
# Надихаюча служба для плану розробки XPlanning Service для Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-uk-t-de-t0-mtec
# Inšpirácia pre službu plánu rozvoja (XPlanGML 5.0.1) pre plán stavebných liniek Rindelbach Rattstadt Am Ortsweg č. 5 mesta Ellwangen (Jagst) (INSPIRE GML)-None-sk-t-de-t0-mtec
# Inspirační služba pro developerský plán XPlanning Service for Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-cs-t-de-t0-mtec
# Завантажити-None-uk-t-en-t0-mtec
# Servizio di ispirazione per il piano di sviluppo XPlanning servizio per la Plan Construction Lines Rindelbach Rattstadt Am Ortsweg n. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-it-t-de-t0-mtec
# Inspiracija za razvojni plan XPlanning usluga za Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-hr-t-de-t0-mtec
# τηλεφόρτωση-None-el-t-en-t0-mtec
# INSPIRE-Dienst für den Bebauungsplan XPlanung-Dienst für den Plan Baulinien Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-de
# INSPIRE Service for the Development Plan Service (XPlanGML 5.0.1) a terv építési vonalak Rindelbach Rattstadt Am Ortsweg No. 5 Ellwangen (Jagst) (INSPIRE GML)-None-hu-t-de-t0-mtec
# INSPIRE paslauga plėtros plano paslaugai (XPlanGML 5.0.1) dėl plano tiesimo linijų Rindelbach Rattstadt Am Ortsweg Nr. 5 Ellwangen (Jagst) (INSPIRE GML)-None-lt-t-de-t0-mtec
# Inspire Service for the Development Plan Service (XPlanGML 5.0.1) för Planbyggnadslinjerna Rindelbach Rattstadt Am Ortsweg No. 5 i staden Ellwangen (Jagst) (INSPIRE GML)-None-sv-t-de-t0-mtec
# Inspiratsiooniteenus arengukava XPlanning teenus Planeerimisliinid Rindelbach Rattstadt Am Ortsweg nr 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-et-t-de-t0-mtec
# télécharger-None-fr-t-en-t0-mtec
# Seirbhís INSPIRE don tSeirbhís um Phlean Forbartha (XPlanGML 5.0.1) do Línte Tógála Phlean Rindelbach Rattstadt Am Ortsweg Uimh. 5 de chathair Ellwangen (Jagst) (INSPIRE GML)-None-ga-t-de-t0-mtec
# 2025-02-08T17:27:04+00:00-http://www.w3.org/2001/XMLSchema#dateTime-None
# Inspire Service for the Development Plan Service (XPlanGML 5.0.1) for Planbyggelinjerne Rindelbach Rattstadt Am Ortsweg Nr. 5 af byen Ellwangen (Jagst) (INSPIRE GML)-None-da-t-de-t0-mtec
# Inspiration service for the development plan XPlanning service for the Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-en-t-de-t0-mtec
# Įkvėpimo paslauga plėtros planui XPlanning paslauga plano statybos linijoms Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-lt-t-de-t0-mtec
# infoFeatureAccessService-None-de
# Bauleitplan-None-de
# stiahnuť-None-sk-t-en-t0-mtec
# Inspiration Service for the Development Plan Service (XPlanGML 5.0.1) dla Plan Building Lines Rindelbach Rattstadt Am Ortsweg Nr 5 miasta Ellwangen (Jagst) (INSPIRE GML)-None-pl-t-de-t0-mtec
# atsiųsti-None-lt-t-en-t0-mtec
# Amt für Stadtentwicklung-None-None
# Надихнути службу для служби плану розвитку (XPlanGML 5.0.1) для Плану будівельних ліній Rindelbach Rattstadt Am Ortsweg No. 5 міста Ellwangen (Jagst) (INSPIRE GML)-None-uk-t-de-t0-mtec
# Serviço INSPIRE para o Serviço do Plano de Desenvolvimento (XPlanGML 5.0.1) para as linhas de construção do plano Rindelbach Rattstadt Am Ortsweg N.º 5 da cidade de Ellwangen (Jagst) (INSPIRE GML)-None-pt-t-de-t0-mtec
# íoslódáil-None-ga-t-en-t0-mtec
# Serviciu de inspirație pentru planul de dezvoltare XPlanning Service pentru Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-ro-t-de-t0-mtec
# INSPIRE teenus arengukava teenusele (XPlanGML 5.0.1) Ellwangeni linna (Jagst) (INSPIRE GML) ehitusliinide Rindelbach Rattstadt Am Ortsweg nr 5 jaoks-None-et-t-de-t0-mtec
# Inspiracija za razvojni načrt XPlanning storitev za Plan Construction Lines Rindelbach Rattstadt Am Ortsweg št. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-sl-t-de-t0-mtec
# Servizz ta’ INSPIRE għas-Servizz tal-Pjan ta’ Żvilupp (XPlanGML 5.0.1) għall-Linji tal-Bini tal-Pjan Rindelbach Rattstadt Rattstadt Am Ortsweg Nru 5 tal-belt ta’ Ellwangen (Jagst) (INSPIRE GML)-None-mt-t-de-t0-mtec
# Iedvesmas pakalpojums attīstības plānam XPlanning pakalpojums Plan Construction Lines Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-lv-t-de-t0-mtec
# Servicio de inspiración para el plan de desarrollo XPlanning Service for the Plan Construction Lines Rindelbach Rattstadt Am Ortsweg N.º 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-es-t-de-t0-mtec
# scarica-None-it-t-en-t0-mtec
# baixar-None-pt-t-en-t0-mtec
# Inspiratiedienst voor het ontwikkelingsplan XPlanning service voor de Plan Construction Lines Rindelbach Rattstadt Am Ortsweg nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-nl-t-de-t0-mtec
# Deutschland-None-None
# Inšpirácia pre plán rozvoja XPlanning služby pre Plán Stavebné linky Rindelbach Rattstadt Am Ortsweg č. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-sk-t-de-t0-mtec
# Spitalstraße 4-None-None
# stáhnout-None-cs-t-en-t0-mtec
# Serviço de inspiração para o plano de desenvolvimento serviço XPlanning para o Plano de Construção Linhas Rindelbach Rattstadt Am Ortsweg N.º 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-pt-t-de-t0-mtec
# 2021-05-17-http://www.w3.org/2001/XMLSchema#date-None
# nedladdning-None-sv-t-en-t0-mtec
# Pobierz-None-pl-t-en-t0-mtec
# Usługa inspiracyjna dla planu rozwoju XPlanning dla Plan Construction Lines Rindelbach Rattstadt Am Ortsweg nr 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-pl-t-de-t0-mtec
# Kehittämissuunnitelman inspiraatiopalvelu Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-fi-t-de-t0-mtec
# Услуга за вдъхновение за устройствения план XPlanning Service за Plan Construction Lines Rindelbach Rattstadt Am Ortsweg № 5 (XPlanGML 5.0.1) (INSPIRE GML)-None-bg-t-de-t0-mtec
# 73479-None-None
# herunterladen-None-de-t-en-t0-mtec
# de-None-None
# tniżżil-None-mt-t-en-t0-mtec
# download-None-en
# INSPIRE-Dienst für den Bebauungsplan Dienst (XPlanGML 5.0.1) für den Plan Baulinien Rindelbach Rattstadt Am Ortsweg Nr. 5 der Stadt Ellwangen (Jagst) (INSPIRE GML)-None-de
# Root Nodes:
# http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440
# FINISHED GETTING ROOT NODES AND LITERALS
#
# STARTING CREATING GRAPH G
# Printing all triples:
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#theme , http://inspire.ec.europa.eu/theme/lu )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , inspireidentifiziert )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/conformsTo , n502f71a6677e4e758cd96184326a9b52b3 )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/creator , http://piveau.io )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#contactPoint , n502f71a6677e4e758cd96184326a9b52b5 )
# ( n502f71a6677e4e758cd96184326a9b52b1 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/prov#Activity )
# ( http://www.opengis.net/def/crs/EPSG/0/25832 , http://purl.org/dc/terms/type , http://inspire.ec.europa.eu/metadata-codelist/SpatialReferenceSystem )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , infoFeatureAccessService )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspiráló szolgáltatás a Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) fejlesztési tervének XPlanning szolgáltatásához )
# ( n502f71a6677e4e758cd96184326a9b52b12 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/prov#Plan )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , Bauleitplan )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , allalaadimine )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , télécharger )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/2006/vcard/ns#fn , Amt für Stadtentwicklung )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Serviço de inspiração para o plano de desenvolvimento serviço XPlanning para o Plano de Construção Linhas Rindelbach Rattstadt Am Ortsweg N.º 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Služba Inspirace pro plán rozvoje (XPlanGML 5.0.1) pro plánovací linky Rindelbach Rattstadt Am Ortsweg č. 5 města Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/prov#wasUsedBy , n502f71a6677e4e758cd96184326a9b52b1 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspirationstjänst för utvecklingsplanen XPlanning för Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://inspire.ec.europa.eu/metadata-codelist/ConditionsApplyingToAccessAndUse/conditionsUnknown , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/LicenseDocument )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/2006/vcard/ns#hasTelephone , tel:+00497961840 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inšpirácia pre plán rozvoja XPlanning služby pre Plán Stavebné linky Rindelbach Rattstadt Am Ortsweg č. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Надихаюча служба для плану розробки XPlanning Service для Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/modified , 2023-02-25 )
# ( n502f71a6677e4e758cd96184326a9b52b11 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/prov#Association )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://xmlns.com/foaf/0.1/primaryTopic , http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 )
# ( n502f71a6677e4e758cd96184326a9b52b3 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/Standard )
# ( n502f71a6677e4e758cd96184326a9b52b2 , http://www.w3.org/ns/dcat#hadRole , http://inspire.ec.europa.eu/metadata-codelist/ResponsiblePartyRole/pointOfContact )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , Bebauungsplan )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Služba INSPIRE za storitev razvojnega načrta (XPlanGML 5.0.1) za projektne linije Rindelbach Rattstadt Am Ortsweg št. 5 mesta Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b8 , http://data.europa.eu/930/serviceType , http://inspire.ec.europa.eu/metadata-codelist/SpatialDataServiceType/download )
# ( n502f71a6677e4e758cd96184326a9b52b2 , http://www.w3.org/ns/prov#agent , n502f71a6677e4e758cd96184326a9b52b15 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Služba za razvojni plan (XPlanGML 5.0.1) za plan izgradnje linija Rindelbach Rattstadt Am Ortsweg br. 5 grada Ellwangena (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspirationsservice til udviklingsplanen XPlanning service til Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspiration service for the development plan XPlanning service for the Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/dcat#Dataset )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/format , http://publications.europa.eu/resource/authority/file-type/WFS_SRVC )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Usługa inspiracyjna dla planu rozwoju XPlanning dla Plan Construction Lines Rindelbach Rattstadt Am Ortsweg nr 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Servizz ta’ ispirazzjoni għas-servizz tal-pjan ta’ żvilupp XPlanning għall-Linji ta’ Kostruzzjoni tal-Pjan Rindelbach Rattstadt Am Ortsweg Nru 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire Service for the Development Plan Service (XPlanGML 5.0.1) for Planbyggelinjerne Rindelbach Rattstadt Am Ortsweg Nr. 5 af byen Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b4 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/Location )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , infraLocal )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#distribution , http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Seirbhís inspioráide don phlean forbartha XPlanning seirbhíse do Phlean Tógála Línte Rindelbach Rattstadt Am Ortsweg Uimh. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , Descarcă )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/dcat#CatalogRecord )
# ( n502f71a6677e4e758cd96184326a9b52b1 , http://www.w3.org/ns/prov#qualifiedAssociation , n502f71a6677e4e758cd96184326a9b52b11 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://xmlns.com/foaf/0.1/isPrimaryTopicOf , n502f71a6677e4e758cd96184326a9b52b6 )
# ( n502f71a6677e4e758cd96184326a9b52b9 , http://www.w3.org/ns/locn#adminUnitL1 , Deutschland )
# ( n502f71a6677e4e758cd96184326a9b52b14 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/prov#Entity )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Serviço INSPIRE para o Serviço do Plano de Desenvolvimento (XPlanGML 5.0.1) para as linhas de construção do plano Rindelbach Rattstadt Am Ortsweg N.º 5 da cidade de Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Service Inspire pour le plan de construction Service (XPlanGML 5.0.1) pour le plan Lignes de construction Rindelbach Rattstadt Am Ortsweg no 5 de la ville d’Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , download )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , stáhnout )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/issued , 2024-02-24T16:23:06+00:00 )
# ( n502f71a6677e4e758cd96184326a9b52b9 , http://www.w3.org/ns/locn#postName , Ellwangen )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspiration Service for the Development Plan Plan Service (XPlanGML 5.0.1) Suunnitelmalinjat Rindelbach Rattstadt Am Ortsweg No. 5 Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , descargar )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Servizz ta’ INSPIRE għas-Servizz tal-Pjan ta’ Żvilupp (XPlanGML 5.0.1) għall-Linji tal-Bini tal-Pjan Rindelbach Rattstadt Rattstadt Am Ortsweg Nru 5 tal-belt ta’ Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , Bebauungspläne )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspiracija za razvojni plan XPlanning usluga za Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Serviciu de inspirație pentru planul de dezvoltare XPlanning Service pentru Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , atsiųsti )
# ( n502f71a6677e4e758cd96184326a9b52b16 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://xmlns.com/foaf/0.1/Organization )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , lataa )
# ( n502f71a6677e4e758cd96184326a9b52b10 , http://purl.org/dc/terms/type , http://inspire.ec.europa.eu/metadata-codelist/DegreeOfConformity/conformant )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dqv#hasQualityMetadata , http://data.europa.eu/88u/metrics/0800af55-8e56-49a0-8986-aa55151d0440 )
# ( n502f71a6677e4e758cd96184326a9b52b13 , http://www.w3.org/2006/vcard/ns#postal-code , 73479 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , INSPIRE Service for the Development Plan Service (XPlanGML 5.0.1) a terv építési vonalak Rindelbach Rattstadt Am Ortsweg No. 5 Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b14 , http://purl.org/dc/terms/issued , 2009-10-20 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspiracija za razvojni načrt XPlanning storitev za Plan Construction Lines Rindelbach Rattstadt Am Ortsweg št. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b12 , http://www.w3.org/ns/prov#wasDerivedFrom , n502f71a6677e4e758cd96184326a9b52b14 )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , scarica )
# ( n502f71a6677e4e758cd96184326a9b52b16 , http://xmlns.com/foaf/0.1/name , Stadt Ellwangen (Jagst) )
# ( n502f71a6677e4e758cd96184326a9b52b8 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/dcat#DataService )
# ( n502f71a6677e4e758cd96184326a9b52b8 , http://data.europa.eu/930/serviceProtocol , http://www.opengeospatial.org/standards/wfs )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , download )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/2006/vcard/ns#hasAddress , n502f71a6677e4e758cd96184326a9b52b13 )
# ( n502f71a6677e4e758cd96184326a9b52b10 , http://purl.org/dc/terms/description , Siehe referenzierte Spezifikation )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inšpirácia pre službu plánu rozvoja (XPlanGML 5.0.1) pre plán stavebných liniek Rindelbach Rattstadt Am Ortsweg č. 5 mesta Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Seirbhís INSPIRE don tSeirbhís um Phlean Forbartha (XPlanGML 5.0.1) do Línte Tógála Phlean Rindelbach Rattstadt Am Ortsweg Uimh. 5 de chathair Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b13 , http://www.w3.org/2006/vcard/ns#street-address , Spitalstraße 4 )
# ( n502f71a6677e4e758cd96184326a9b52b13 , http://www.w3.org/2006/vcard/ns#region , Baden-Württemberg )
# ( n502f71a6677e4e758cd96184326a9b52b7 , http://spdx.org/rdf/terms#checksumValue , 4c30b434751d57dd0212dc3433813e61 )
# ( http://inspire.ec.europa.eu/metadata-codelist/LimitationsOnPublicAccess/noLimitations , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/RightsStatement )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , letöltés )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://xmlns.com/foaf/0.1/homepage , http://www.ellwangen.de )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire Service for the Development Plan Service (XPlanGML 5.0.1) voor de Plan Building Lines Rindelbach Rattstadt Am Ortsweg nr. 5 van de stad Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Услуга за вдъхновение за устройствения план XPlanning Service за Plan Construction Lines Rindelbach Rattstadt Am Ortsweg № 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b9 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/locn#Address )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://www.w3.org/ns/org#memberOf , n502f71a6677e4e758cd96184326a9b52b16 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/created , 2021-05-17 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/spatial , n502f71a6677e4e758cd96184326a9b52b4 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Servizio Ispirare per il Piano di Sviluppo Servizio (XPlanGML 5.0.1) per la Plan Building Lines Rindelbach Rattstadt Am Ortsweg No. 5 della città di Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://www.w3.org/ns/dcat#accessURL , https://haleconnect.com/ows/services/org.948.bd20136c-24fd-487e-91d2-bfb5d20320d2_wfs/org.948.aad7019f-303c-4e6c-8b7e-bb80cca07a15?SERVICE=WFS&Request=GetCapabilities )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/accessRights , http://inspire.ec.europa.eu/metadata-codelist/LimitationsOnPublicAccess/noLimitations )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire Service for the Development Plan Service (XPlanGML 5.0.1) for the Plan Building Lines Rindelbach Rattstadt Am Ortsweg No. 5 of the city of Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , изтегли )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://www.w3.org/ns/dcat#accessService , n502f71a6677e4e758cd96184326a9b52b8 )
# ( n502f71a6677e4e758cd96184326a9b52b10 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/prov#Entity )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , herunterladen )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspiration Service for the Development Plan Service (XPlanGML 5.0.1) dla Plan Building Lines Rindelbach Rattstadt Am Ortsweg Nr 5 miasta Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , lejupielādēt )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://xmlns.com/foaf/0.1/phone , tel:+00497961840 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Įkvėpimo paslauga plėtros planui XPlanning paslauga plano statybos linijoms Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b3 , http://purl.org/dc/terms/title , VERORDNUNG (EG) Nr. 976/2009 DER KOMMISSION vom 19. Oktober 2009 zur Durchführung der Richtlinie 2007/2/EG des Europäischen Parlaments und des Rates hinsichtlich der Netzdienste )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , tniżżil )
# ( n502f71a6677e4e758cd96184326a9b52b8 , http://www.w3.org/ns/dcat#endpointURL , https://haleconnect.com/ows/services/org.948.bd20136c-24fd-487e-91d2-bfb5d20320d2_wfs/org.948.aad7019f-303c-4e6c-8b7e-bb80cca07a15 )
# ( n502f71a6677e4e758cd96184326a9b52b14 , http://purl.org/dc/terms/title , VERORDNUNG (EG) Nr. 976/2009 DER KOMMISSION vom 19. Oktober 2009 zur Durchführung der Richtlinie 2007/2/EG des Europäischen Parlaments und des Rates hinsichtlich der Netzdienste )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/dcat#keyword , PlannedLandUse )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://xmlns.com/foaf/0.1/Person )
# ( n502f71a6677e4e758cd96184326a9b52b9 , http://www.w3.org/ns/locn#thoroughfare , Spitalstraße 4 )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , preuzimanje )
# ( n502f71a6677e4e758cd96184326a9b52b1 , http://www.w3.org/ns/prov#generated , n502f71a6677e4e758cd96184326a9b52b10 )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://xmlns.com/foaf/0.1/mbox , mailto:Stadtplanung@Ellwangen.de )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://xmlns.com/foaf/0.1/name , Amt für Stadtentwicklung )
# ( http://www.opengis.net/def/crs/EPSG/0/25832 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/Standard )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , INSPIRE paslauga plėtros plano paslaugai (XPlanGML 5.0.1) dėl plano tiesimo linijų Rindelbach Rattstadt Am Ortsweg Nr. 5 Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b9 , http://www.w3.org/ns/locn#adminUnitL2 , Baden-Württemberg )
# ( n502f71a6677e4e758cd96184326a9b52b13 , http://www.w3.org/2006/vcard/ns#locality , Ellwangen )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/2006/vcard/ns#hasEmail , mailto:Stadtplanung@Ellwangen.de )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Kehittämissuunnitelman inspiraatiopalvelu Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , íoslódáil )
# ( n502f71a6677e4e758cd96184326a9b52b13 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/2006/vcard/ns#Address )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , τηλεφόρτωση )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspirační služba pro developerský plán XPlanning Service for Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspiratiedienst voor het ontwikkelingsplan XPlanning service voor de Plan Construction Lines Rindelbach Rattstadt Am Ortsweg nr. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Iedvesmas pakalpojums attīstības plānam XPlanning pakalpojums Plan Construction Lines Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/issued , 2021-05-17 )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/license , http://inspire.ec.europa.eu/metadata-codelist/ConditionsApplyingToAccessAndUse/conditionsUnknown )
# ( n502f71a6677e4e758cd96184326a9b52b7 , http://spdx.org/rdf/terms#algorithm , http://spdx.org/rdf/terms#checksumAlgorithm_md5 )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , Pobierz )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , INSPIRE-Dienst für den Bebauungsplan Dienst (XPlanGML 5.0.1) für den Plan Baulinien Rindelbach Rattstadt Am Ortsweg Nr. 5 der Stadt Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Надихнути службу для служби плану розвитку (XPlanGML 5.0.1) для Плану будівельних ліній Rindelbach Rattstadt Am Ortsweg No. 5 міста Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://www.w3.org/ns/prov#qualifiedAttribution , n502f71a6677e4e758cd96184326a9b52b2 )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/identifier , "download"@en )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Servicio de inspiración para el Servicio del Plan de Desarrollo (XPlanGML 5.0.1) para las líneas de construcción del Plan Rindelbach Rattstadt Am Ortsweg N.º 5 de la ciudad de Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b13 , http://www.w3.org/2006/vcard/ns#country-name , Deutschland )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Service Inspire pour le plan d’aménagement XPlan pour le plan Lignes de construction Rindelbach Rattstadt Am Ortsweg no 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Inspiratsiooniteenus arengukava XPlanning teenus Planeerimisliinid Rindelbach Rattstadt Am Ortsweg nr 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , Завантажити )
# ( n502f71a6677e4e758cd96184326a9b52b2 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/prov#Attribution )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , stiahnuť )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://data.europa.eu/930/referenceSystem , http://www.opengis.net/def/crs/EPSG/0/25832 )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/2006/vcard/ns#organization-name , Stadt Ellwangen (Jagst) )
# ( n502f71a6677e4e758cd96184326a9b52b15 , http://www.w3.org/ns/locn#address , n502f71a6677e4e758cd96184326a9b52b9 )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/modified , 2025-02-08T17:27:04+00:00 )
# ( n502f71a6677e4e758cd96184326a9b52b8 , http://www.w3.org/ns/dcat#endpointDescription , https://haleconnect.com/ows/services/org.948.bd20136c-24fd-487e-91d2-bfb5d20320d2_wfs/org.948.aad7019f-303c-4e6c-8b7e-bb80cca07a15?SERVICE=WFS&Request=GetCapabilities )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , download )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , baixar )
# ( n502f71a6677e4e758cd96184326a9b52b8 , http://purl.org/dc/terms/title , WFS )
# ( n502f71a6677e4e758cd96184326a9b52b3 , http://purl.org/dc/terms/issued , 2009-10-20 )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , https://europeandataportal.eu/voc#transReceived , 2024-09-23T04:54:37+00:00 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Servicio de inspiración para el plan de desarrollo XPlanning Service for the Plan Construction Lines Rindelbach Rattstadt Am Ortsweg N.º 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Servizio di ispirazione per il piano di sviluppo XPlanning servizio per la Plan Construction Lines Rindelbach Rattstadt Am Ortsweg n. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Serviciul Inspirație pentru Planul de Dezvoltare (XPlanGML 5.0.1) pentru liniile de construcție a planului Rindelbach Rattstadt Am Ortsweg nr. 5 din orașul Ellwangen (Jagst) (INSPIRE GML) )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , https://europeandataportal.eu/voc#originalLanguage , de )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , https://europeandataportal.eu/voc#transIssued , 2024-06-15T16:46:47+00:00 )
# ( n502f71a6677e4e758cd96184326a9b52b4 , http://www.w3.org/ns/dcat#bbox , POLYGON((10.17145992406387 48.974835601138444,10.173266397790224 48.974835601138444,10.173266397790224 48.97286574139233,10.17145992406387 48.97286574139233,10.17145992406387 48.974835601138444)) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , INSPIRE teenus arengukava teenusele (XPlanGML 5.0.1) Ellwangeni linna (Jagst) (INSPIRE GML) ehitusliinide Rindelbach Rattstadt Am Ortsweg nr 5 jaoks )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , Υπηρεσία έμπνευσης για το σχέδιο ανάπτυξης της υπηρεσίας XPlanning για τις γραμμές κατασκευής σχεδίου Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire Service for the Development Plan Service (XPlanGML 5.0.1) за Plan Building Lines Rindelbach Rattstadt Am Ortsweg № 5 на град Ellwangen (Jagst) (INSPIRE GML) )
# ( http://www.opengeospatial.org/standards/wfs , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/Standard )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/2006/vcard/ns#Individual )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://www.w3.org/ns/dcat#Distribution )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/identifier , 0800af55-8e56-49a0-8986-aa55151d0440 )
# ( n502f71a6677e4e758cd96184326a9b52b7 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://spdx.org/rdf/terms#Checksum )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire Service for the Development Plan Service (XPlanGML 5.0.1) för Planbyggnadslinjerna Rindelbach Rattstadt Am Ortsweg No. 5 i staden Ellwangen (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b5 , http://www.w3.org/2006/vcard/ns#hasURL , http://www.ellwangen.de )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire Service for the Development Plan Service (XPlanGML 5.0.1) για τις γραμμές κατασκευής σχεδίων Rindelbach Rattstadt Am Ortsweg No. 5 της πόλης Ellwangen (Jagst) (INSPIRE GML) )
# ( http://publications.europa.eu/resource/authority/file-type/WFS_SRVC , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://purl.org/dc/terms/MediaType )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , prenos )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , http://spdx.org/rdf/terms#checksum , n502f71a6677e4e758cd96184326a9b52b7 )
# ( n502f71a6677e4e758cd96184326a9b52b11 , http://www.w3.org/ns/prov#hadPlan , n502f71a6677e4e758cd96184326a9b52b12 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/description , Inspire pakalpojums attīstības plāna pakalpojumam (XPlanGML 5.0.1) Elvangenas pilsētas (Jagst) 5. plāna būvei Rindelbach Rattstadt Am Ortsweg (Jagst) (INSPIRE GML) )
# ( n502f71a6677e4e758cd96184326a9b52b9 , http://www.w3.org/ns/locn#postCode , 73479 )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://purl.org/dc/terms/title , INSPIRE-Dienst für den Bebauungsplan XPlanung-Dienst für den Plan Baulinien Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML) )
# ( http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440 , http://data.europa.eu/930/resourceType , http://inspire.ec.europa.eu/metadata-codelist/ResourceType/dataset )
# ( http://data.europa.eu/88u/distribution/cf999407-65ae-49ad-882c-b9a1c812810f , http://purl.org/dc/terms/title , nedladdning )
# ( http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440 , https://europeandataportal.eu/voc#transStatus , https://europeandataportal.eu/voc#TransCompleted )
# FINISHED CREATING GRAPH G
#
# STARTING CALCULATING PATHS
# Starting searching for paths with root node: http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440
# FINISHED CALCULATING PATHS
#
# FOUND PATHS:
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://piveau.io']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'http://inspire.ec.europa.eu/theme/lu']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'inspireidentifiziert_None_de']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b3', 'http://purl.org/dc/terms/Standard']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b3', 'VERORDNUNG (EG) Nr. 976/2009 DER KOMMISSION vom 19. Oktober 2009 zur Durchführung der Richtlinie 2007/2/EG des Europäischen Parlaments und des Rates hinsichtlich der Netzdienste_None_de']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b3', '2009-10-20_http://www.w3.org/2001/XMLSchema#date_None']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'Amt für Stadtentwicklung_None_None']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'tel:+00497961840']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'n502f71a6677e4e758cd96184326a9b52b13', '73479_None_None']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'n502f71a6677e4e758cd96184326a9b52b13', 'Spitalstraße 4_None_None']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'n502f71a6677e4e758cd96184326a9b52b13', 'Baden-Württemberg_None_None']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'n502f71a6677e4e758cd96184326a9b52b13', 'Ellwangen_None_None']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'n502f71a6677e4e758cd96184326a9b52b13', 'http://www.w3.org/2006/vcard/ns#Address']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'n502f71a6677e4e758cd96184326a9b52b13', 'Deutschland_None_None']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'mailto:Stadtplanung@Ellwangen.de']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'Stadt Ellwangen (Jagst)_None_None']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'http://www.w3.org/2006/vcard/ns#Individual']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b5', 'http://www.ellwangen.de']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'infoFeatureAccessService_None_de']
# Path length = 2
# ...
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Servizio Ispirare per il Piano di Sviluppo Servizio (XPlanGML 5.0.1) per la Plan Building Lines Rindelbach Rattstadt Am Ortsweg No. 5 della città di Ellwangen (Jagst) (INSPIRE GML)_None_it-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspire Service for the Development Plan Service (XPlanGML 5.0.1) for the Plan Building Lines Rindelbach Rattstadt Am Ortsweg No. 5 of the city of Ellwangen (Jagst) (INSPIRE GML)_None_en-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspiration Service for the Development Plan Service (XPlanGML 5.0.1) dla Plan Building Lines Rindelbach Rattstadt Am Ortsweg Nr 5 miasta Ellwangen (Jagst) (INSPIRE GML)_None_pl-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Įkvėpimo paslauga plėtros planui XPlanning paslauga plano statybos linijoms Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_lt-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'PlannedLandUse_None_de']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'INSPIRE paslauga plėtros plano paslaugai (XPlanGML 5.0.1) dėl plano tiesimo linijų Rindelbach Rattstadt Am Ortsweg Nr. 5 Ellwangen (Jagst) (INSPIRE GML)_None_lt-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Kehittämissuunnitelman inspiraatiopalvelu Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_fi-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspirační služba pro developerský plán XPlanning Service for Plan Construction Lines Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_cs-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspiratiedienst voor het ontwikkelingsplan XPlanning service voor de Plan Construction Lines Rindelbach Rattstadt Am Ortsweg nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_nl-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Iedvesmas pakalpojums attīstības plānam XPlanning pakalpojums Plan Construction Lines Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_lv-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'INSPIRE-Dienst für den Bebauungsplan Dienst (XPlanGML 5.0.1) für den Plan Baulinien Rindelbach Rattstadt Am Ortsweg Nr. 5 der Stadt Ellwangen (Jagst) (INSPIRE GML)_None_de']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Надихнути службу для служби плану розвитку (XPlanGML 5.0.1) для Плану будівельних ліній Rindelbach Rattstadt Am Ortsweg No. 5 міста Ellwangen (Jagst) (INSPIRE GML)_None_uk-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'http://inspire.ec.europa.eu/metadata-codelist/ResponsiblePartyRole/pointOfContact']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'http://www.ellwangen.de']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b16', 'http://xmlns.com/foaf/0.1/Organization']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b16', 'Stadt Ellwangen (Jagst)_None_None']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'tel:+00497961840']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'http://xmlns.com/foaf/0.1/Person']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'mailto:Stadtplanung@Ellwangen.de']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'Amt für Stadtentwicklung_None_None']
# Path length = 4
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b9', 'Deutschland_None_None']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b9', 'Ellwangen_None_None']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b9', 'http://www.w3.org/ns/locn#Address']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b9', 'Spitalstraße 4_None_None']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b9', 'Baden-Württemberg_None_None']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'n502f71a6677e4e758cd96184326a9b52b15', 'n502f71a6677e4e758cd96184326a9b52b9', '73479_None_None']
# Path length = 5
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b2', 'http://www.w3.org/ns/prov#Attribution']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Servicio de inspiración para el Servicio del Plan de Desarrollo (XPlanGML 5.0.1) para las líneas de construcción del Plan Rindelbach Rattstadt Am Ortsweg N.º 5 de la ciudad de Ellwangen (Jagst) (INSPIRE GML)_None_es-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Service Inspire pour le plan d’aménagement XPlan pour le plan Lignes de construction Rindelbach Rattstadt Am Ortsweg no 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_fr-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspiratsiooniteenus arengukava XPlanning teenus Planeerimisliinid Rindelbach Rattstadt Am Ortsweg nr 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_et-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'http://www.opengis.net/def/crs/EPSG/0/25832', 'http://inspire.ec.europa.eu/metadata-codelist/SpatialReferenceSystem']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'http://www.opengis.net/def/crs/EPSG/0/25832', 'http://purl.org/dc/terms/Standard']
# Path length = 3
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Servicio de inspiración para el plan de desarrollo XPlanning Service for the Plan Construction Lines Rindelbach Rattstadt Am Ortsweg N.º 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_es-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Servizio di ispirazione per il piano di sviluppo XPlanning servizio per la Plan Construction Lines Rindelbach Rattstadt Am Ortsweg n. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_it-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Serviciul Inspirație pentru Planul de Dezvoltare (XPlanGML 5.0.1) pentru liniile de construcție a planului Rindelbach Rattstadt Am Ortsweg nr. 5 din orașul Ellwangen (Jagst) (INSPIRE GML)_None_ro-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'INSPIRE teenus arengukava teenusele (XPlanGML 5.0.1) Ellwangeni linna (Jagst) (INSPIRE GML) ehitusliinide Rindelbach Rattstadt Am Ortsweg nr 5 jaoks_None_et-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Υπηρεσία έμπνευσης για το σχέδιο ανάπτυξης της υπηρεσίας XPlanning για τις γραμμές κατασκευής σχεδίου Rindelbach Rattstadt Am Ortsweg No. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_el-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspire Service for the Development Plan Service (XPlanGML 5.0.1) за Plan Building Lines Rindelbach Rattstadt Am Ortsweg №\xa05 на град Ellwangen (Jagst) (INSPIRE GML)_None_bg-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspire Service for the Development Plan Service (XPlanGML 5.0.1) för Planbyggnadslinjerna Rindelbach Rattstadt Am Ortsweg No. 5 i staden Ellwangen (Jagst) (INSPIRE GML)_None_sv-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspire Service for the Development Plan Service (XPlanGML 5.0.1) για τις γραμμές κατασκευής σχεδίων Rindelbach Rattstadt Am Ortsweg No. 5 της πόλης Ellwangen (Jagst) (INSPIRE GML)_None_el-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'Inspire pakalpojums attīstības plāna pakalpojumam (XPlanGML 5.0.1) Elvangenas pilsētas (Jagst) 5. plāna būvei Rindelbach Rattstadt Am Ortsweg (Jagst) (INSPIRE GML)_None_lv-t-de-t0-mtec']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'INSPIRE-Dienst für den Bebauungsplan XPlanung-Dienst für den Plan Baulinien Rindelbach Rattstadt Am Ortsweg Nr. 5 (XPlanGML 5.0.1) (INSPIRE GML)_None_de']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/dataset/0800af55-8e56-49a0-8986-aa55151d0440', 'http://inspire.ec.europa.eu/metadata-codelist/ResourceType/dataset']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://www.w3.org/ns/dcat#CatalogRecord']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', '2024-02-24T16:23:06+00:00_http://www.w3.org/2001/XMLSchema#dateTime_None']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'http://data.europa.eu/88u/metrics/0800af55-8e56-49a0-8986-aa55151d0440']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', '2025-02-08T17:27:04+00:00_http://www.w3.org/2001/XMLSchema#dateTime_None']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', '2024-09-23T04:54:37+00:00_http://www.w3.org/2001/XMLSchema#dateTime_None']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'de_None_None']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', '2024-06-15T16:46:47+00:00_http://www.w3.org/2001/XMLSchema#dateTime_None']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', '0800af55-8e56-49a0-8986-aa55151d0440_None_None']
# Path length = 1
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b7', '4c30b434751d57dd0212dc3433813e61_None_None']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b7', 'http://spdx.org/rdf/terms#checksumAlgorithm_md5']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'n502f71a6677e4e758cd96184326a9b52b7', 'http://spdx.org/rdf/terms#Checksum']
# Path length = 2
# ['http://data.europa.eu/88u/record/0800af55-8e56-49a0-8986-aa55151d0440', 'https://europeandataportal.eu/voc#TransCompleted']
# Path length = 1
# RESULTS:
# -Number of Paths: 156
# -Absolute depth: 434
# -Average depth: 2.782051282051282
# -Maximal depth: 6

# %%
# Tangledness 
# source 73 - page 4
# tangledness = mean number of classes with more than 1 direct ancestor, so two primitive 
# measurements (number of classes and number of direct ancestors) are used for computing the metric 

# Select number of classes in graph 
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT (COUNT(DISTINCT ?class) AS ?num_classes)
WHERE {
  {
    # 1. explicitly/implicitly used RDF classes
    # explicitly: ?class a owl:Class . or ?class a rdfs:Class .
    # implicitly: ?any rdf:type ?class . (includes also explicitly used classes)

    # ?any rdf:type ?class .
  }
  UNION
  {
    # 2. subclasses
    # ?class rdfs:subClassOf ?any .
  }
  UNION
  {
    # 3. superclasses
    # ?any rdfs:subClassOf ?class .
  }
  UNION
  {
    # 4. classes used with owl:equivalentClass
    { ?class owl:equivalentClass ?any . }
    UNION
    { ?any owl:equivalentClass ?class . }
  }
  UNION
  {
    # 5. OWL restriction classes
    # ?class a owl:Restriction .
  }
  UNION
  {
    # 6. complex classes with using unionOf, intersectionOf etc.
    # ?class owl:unionOf|owl:intersectionOf|owl:complementOf|owl:oneOf ?list .
  }
  UNION
  {
    # 7. OWL hasValue restrictions
    # ?class owl:hasValue ?val .
  }
}"""

res = g.query(query)
for row in res:
    print("Number of classes in graph: " + str(row['num_classes']))
    num_classes = int(row['num_classes'])

# Select number of classes with more than one ingoing isA arc (Dr. Jovanovik said I should use is-a)
query_var1 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(?class) AS ?tangledCount)
WHERE
{
  SELECT ?class (COUNT(?s) AS ?numIngoing)
  WHERE {
    { ?s rdf:type ?class . }
  }
  GROUP BY ?class
  HAVING (COUNT(?s) > 1) # problem here was: i used ?numIngoing instead of COUNT(?s)
}
"""

# Select number of classes with more than one superclass (source says I should use this query)
query_var2 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(?class) AS ?tangledCount)
WHERE {
  SELECT ?class (COUNT(?super) AS ?numSupers)
  WHERE {
    # ?class rdfs:subClassOf ?super .
  }
  GROUP BY ?class
  HAVING (COUNT(?super) > 1)
}
"""
res = g.query(query_var2)

t = 0

for row in res:
  print("Number of classes with more than one superclass: " + str(row["tangledCount"]) )
  t = int(row["tangledCount"])
  #print("Class " + str(row["class"]) + ": " + str(row["numIngoing"]))

#print("t: " + str(t))

print("\nRESULT:")

if t > 0:
  # source 37 says num_classes / t
  # source 73 says denominator and numerator should be switched -> t / num_classes
  ont_tangledness = round(num_classes / t, DEC_PLACES) 
else:
  ont_tangledness = 0.0

print("-Ontology Tangledness: " + str(ont_tangledness))
# Out:
# Number of classes in graph: 8
# Number of classes with more than one superclass: 0
#
# RESULT:
# -Ontology Tangledness: 0.0

# %%
# Degree Distribution (Formula in: source 37, page 7)
# nG...number of nodes in gaph
# nE...number of edges in graph

print("STARTING CALCULATING DEGREE DISTRIBUTION")

# Calculating nE
query_nE = """
SELECT (COUNT(*) AS ?tripleCount)
WHERE {
  # ?s ?p ?o .
}
"""

res = g.query(query_nE)
for row in res:
    print("Number of edges in graph: " + str(row['tripleCount']))
    nE = int(row['tripleCount'])

# Calculating nG
query_nG = """
SELECT (COUNT(DISTINCT ?node) AS ?nodeCount)
WHERE {
  {
    SELECT ?node WHERE {
      { ?node ?p1 ?o }       
      UNION
      { ?s ?p2 ?node }       
    }
  }
}
"""

res = g.query(query_nG)

for row in res:
    print("Number of nodes in graph: " + str(row['nodeCount']))
    nG = int(row['nodeCount'])

# Calculating degree for every node in graph
query_degrees = """
SELECT ?node (COUNT(?any) AS ?degree)
WHERE {
  {
    { ?node ?p1 ?any }    
    UNION
    { ?any ?p2 ?node }    
  }
}
GROUP BY ?node
"""

# sum_of_degress = 0
degrees = []

res = g.query(query_degrees)

for row in res:
    #sum_of_degress += int(row['degree'])
    node = row["node"]
    degree = int(row["degree"])
    degrees.append((node, degree))
    debug_print(str(node) + " - Degree: " + str(degree))

# Summe aller Degrees
sum_of_degrees = sum(d for _, d in degrees)

print("\nSum of Degrees: " + str(sum_of_degrees))

if nG > 1:
  mean_degree = (2 * nE) / nG
  squared_diffs = [(deg_v - mean_degree) ** 2 for _,deg_v in degrees]
  degree_distribution = round(sum(squared_diffs) / (nG-1), 2)
else:
  degree_distribution = 0.0 

print("FINISHED CALCULATING DEGREE DISTRIBUTION")

print("\nRESULT:")
print("-Degree Distribution: " + str(degree_distribution))
# Out:
# STARTING CALCULATING DEGREE DISTRIBUTION
# Number of edges in graph: 38
# Number of nodes in graph: 30
# http://example.org/ontology#manages - Degree: 4
# http://example.org/ontology#Ontology - Degree: 1
# http://example.org/ontology#johnDoe - Degree: 4
# http://example.org/ontology#deptIT - Degree: 5
# http://example.org/ontology#hasName - Degree: 4
# http://example.org/ontology#hasSalary - Degree: 4
# http://example.org/ontology#Manager - Degree: 5
# http://example.org/ontology#janeSmith - Degree: 5
# http://example.org/ontology#Employee - Degree: 7
# http://example.org/ontology#worksIn - Degree: 4
# http://example.org/ontology#Person - Degree: 4
# http://example.org/ontology#Department - Degree: 5
# manages department - Degree: 1
# http://www.w3.org/2002/07/owl#Ontology - Degree: 1
# 45000 - Degree: 1
# IT Department - Degree: 1
# http://www.w3.org/2002/07/owl#DatatypeProperty - Degree: 2
# Manager - Degree: 1
# http://www.w3.org/2000/01/rdf-schema#Literal - Degree: 2
# Employee - Degree: 1
# works in - Degree: 1
# http://www.w3.org/2002/07/owl#ObjectProperty - Degree: 2
# Jane Smith - Degree: 1
# 70000 - Degree: 1
# John Doe - Degree: 1
# http://www.w3.org/2002/07/owl#Class - Degree: 4
# has name - Degree: 1
# Person - Degree: 1
# has salary - Degree: 1
# Department - Degree: 1
#
# Sum of Degrees: 76
# FINISHED CALCULATING DEGREE DISTRIBUTION
#
# RESULT:
# -Degree Distribution: 3.29

# %%
print("STARTING CALCULATING ENTITIES/CLASSES/PROPERTIES/INSTANCES/OBJECT PROPERTIES")

# TODO: Entities
query_entitities = """
SELECT (COUNT(DISTINCT ?entity) AS ?entityCount)
WHERE {
  {
    SELECT DISTINCT ?entity WHERE {
      # ?entity ?p ?o .
    }
  }
  UNION
  {
    SELECT DISTINCT ?entity WHERE {
      # ?s ?p ?entity .
      FILTER(!isLiteral(?entity))
    }
  }
}
"""

res = g.query(query_entitities)

num_entities = 0

for row in res:
  num_entities = int(row["entityCount"])


# Number of instances per type
query_inst = """ 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT ?type (COUNT(?s) AS ?count)
WHERE {
  # ?s rdf:type ?type . 
}
GROUP BY ?type """

res = g.query(query_inst)

num_instances = 0

for row in res:
  rdf_type = row["type"]
  count = int(row["count"])
  debug_print("Number of instancees of " + str(rdf_type) + ": " + str(count))
  num_instances += count

# Number of classes
# Defintion of Class: 
# source: 213, page: 5 - source: 250, page: 3
# TNOC (total number of classes/concepts) = classes, subclasses, superclasses, anonymous classes
# anonymous classes = equivalent/restriction/unionOf/intersectionOf/complementOf/oneOf/hasValue classes

query_classes = """ 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?class
WHERE {
  {
    # 1. explicitly/implicitly used RDF classes
    # explicitly: ?class a owl:Class . or ?class a rdfs:Class .
    # implicitly: ?any rdf:type ?class . (includes also explicitly used classes)

    # ?any rdf:type ?class .
  }
  UNION
  {
    # 2. subclasses
    # ?class rdfs:subClassOf ?any .
  }
  UNION
  {
    # 3. superclasses
    # ?any rdfs:subClassOf ?class .
  }
  UNION
  {
    # 4. classes used with owl:equivalentClass
    { ?class owl:equivalentClass ?any . }
    UNION
    { ?any owl:equivalentClass ?class . }
  }
  UNION
  {
    # 5. OWL restriction classes
    # ?class a owl:Restriction .
  }
  UNION
  {
    # 6. complex classes with using unionOf, intersectionOf etc.
    # ?class owl:unionOf|owl:intersectionOf|owl:complementOf|owl:oneOf ?list .
  }
  UNION
  {
    # 7. OWL hasValue restrictions
    # ?class owl:hasValue ?val .
  }
}
"""
res = g.query(query_classes)

num_classes = 0

debug_print("\nExisting classes: ")

for row in res:
  num_classes += 1
  debug_print("Class " + str(num_classes) + ": " + str(row["class"]))

# number of properties in T-Box
# source says: property = explicitly defined property
query_properties_t = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(DISTINCT ?property) AS ?propertyCount)
WHERE {
  VALUES ?type { owl:ObjectProperty owl:DatatypeProperty owl:AnnotationProperty }
  # ?property rdf:type ?type .
}
"""

res = g.query(query_properties_t)

num_properties_t = 0

for row in res:
  num_properties_t = int(row["propertyCount"])

# number of properties in A-Box
# source says: property = the unique ?p in ?s ?p ?o
query_properties_a = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(DISTINCT ?p) AS ?propertyCount)
WHERE {
  # ?s ?p ?o .
}
"""
res = g.query(query_properties_a)

num_properties_a = 0

for row in res:
  num_properties_a = int(row["propertyCount"])

debug_print("Properties in T-Box: " + str(num_properties_t))
debug_print("Properties in A-Box: " + str(num_properties_a))

num_properties = num_properties_t + num_properties_a

# Number of object properties in T-Box
# Non-Inheritance -> excluding inheritance properties like rdfs:subPropertyOf or rdfs:subClassOf
query_object_properties_t = """
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT (COUNT(DISTINCT ?property) AS ?numObjectProperties)
WHERE {
  # ?property rdf:type owl:ObjectProperty .
}
"""

res = g.query(query_object_properties_t)

num_obj_properties_t = 0

for row in res:
  num_obj_properties_t = int(row["numObjectProperties"])

# Number of object properties in A-Box
# Non-Inheritance -> excluding inheritance properties like rdfs:subPropertyOf or rdfs:subClassOf
query_object_properties_a = """
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT (COUNT(DISTINCT ?property) AS ?numObjectProperties)
WHERE {
  # ?s ?property ?o 
  Filter(!isLiteral(?o))
}
"""

res = g.query(query_object_properties_a)

num_obj_properties_a = 0

for row in res:
  num_obj_properties_a = int(row["numObjectProperties"])

debug_print("Object Properties in T-Box: " + str(num_obj_properties_t))
debug_print("Object Properties in A-Box: " + str(num_obj_properties_a))
num_obj_properties = num_obj_properties_t + num_obj_properties_a

print("FINISHED CALCULATING ENTITIES/CLASSES/PROPERTIES/INSTANCES/OBJECT PROPERTIES")

print("\nRESULTS:")
print("-Number of entities: TODO")
print("-Number of properties: " + str(num_properties))
print("-Number of classes: " + str(num_classes))
print("-Number of instances: " + str(num_instances))
print("-Number of object properties: " + str(num_obj_properties))
# Out:
# STARTING CALCULATING ENTITIES/CLASSES/PROPERTIES/INSTANCES/OBJECT PROPERTIES
# Number of instancees of http://www.w3.org/2002/07/owl#Ontology: 1
# Number of instancees of http://www.w3.org/2002/07/owl#Class: 4
# Number of instancees of http://www.w3.org/2002/07/owl#ObjectProperty: 2
# Number of instancees of http://www.w3.org/2002/07/owl#DatatypeProperty: 2
# Number of instancees of http://example.org/ontology#Department: 1
# Number of instancees of http://example.org/ontology#Employee: 1
# Number of instancees of http://example.org/ontology#Manager: 1
#
# Existing classes:
# Class 1: http://www.w3.org/2002/07/owl#Ontology
# Class 2: http://www.w3.org/2002/07/owl#Class
# Class 3: http://www.w3.org/2002/07/owl#ObjectProperty
# Class 4: http://www.w3.org/2002/07/owl#DatatypeProperty
# Class 5: http://example.org/ontology#Department
# Class 6: http://example.org/ontology#Employee
# Class 7: http://example.org/ontology#Manager
# Class 8: http://example.org/ontology#Person
# Properties in T-Box: 4
# Properties in A-Box: 9
# Object Properties in T-Box: 2
# Object Properties in A-Box: 6
# FINISHED CALCULATING ENTITIES/CLASSES/PROPERTIES/INSTANCES/OBJECT PROPERTIES
#
# RESULTS:
# -Number of entities: TODO
# -Number of properties: 13
# -Number of classes: 8
# -Number of instances: 12
# -Number of object properties: 8

# %%
# TODO: Depth of Inheritance Tree

print("STARTING CALCULATING DEPTH OF INHERITANCE TREE")

# Calculating all paths from one root node (start node) for a sparql endpoint
def find_all_paths_subclasses(endpoint_url, default_graph, start_node):
    neighbors_cache = {}  # global oder in der Funktion definiert

    # helperfunction for finding neighbors of a node (triple=(node, pred, neighbor))
    def get_neighbors(node):
        
        node_str = str(node)

        # 1. Prüfen, ob der Node bereits im Cache ist
        if node_str in neighbors_cache:
            # Debug-Ausgabe
            #print(f"Cache-Treffer für {node_str}")
            return neighbors_cache[node_str]
 
        if (len(str(node)) == 0): #or (not (node.startswith("http://") or node.startswith("https://"))):
            return [] 

        query = f"""
        PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

        SELECT DISTINCT ?child
        WHERE {{
          # ?child rdfs:subClassOf <{node}> .
        }}
        """
        
        #sparql.setQuery(query)
        #sparql.setReturnFormat(JSON)
        #sparql.addDefaultGraph(default_graph)
        res = g.query(query)
       
        
        neighbors = []
        for row in res:
            next_obj = binding["next"]
            value = next_obj["value"]
            value_type = next_obj["type"]  # 'uri', 'literal', 'bnode'
        
            neighbors.append((value, value_type))

        neighbors_cache[node_str] = neighbors

        return neighbors
    
    def dfs(path, node, node_type="uri"):
        global num_paths_inh_tree
        global max_depth_inh_tree

        # skip node if it already is in path (avoiding cycles)
        if node in path:
            return
        
        # add current node to path
        path.append(node)
        
        neighbors = list(get_neighbors(node)) 

        if not neighbors:
            paths.append(list(path))
            num_paths_inh_tree += 1
            max_depth_inh_tree = max(max_depth_inh_tree, len(path) - 1)
        else:
            for neighbor, neighbor_type in neighbors:
              #print("\node: " + str(node) + " - neighbor: " + str(neighbor))
              
              dfs(path, neighbor, neighbor_type)

        # remove node from the path to find next path
        path.pop()

    sparql = SPARQLWrapper(endpoint_url)
    sparql.addDefaultGraph(default_graph)
    #sparql.setTimeout(60)  # 120 Sekunden Timeout

    # list which stores all paths
    paths = []

    # TODO: ich glaub dass node_type=uri nicht passt, weil bnodes auch vorkommen können (vllt passts aber auch mt uri weil gleich gesucht wird mit bnodes)
    dfs([], start_node, node_type="uri")

    return paths

# %%
print("STARTING CALCULATING PROPERTY CLASS RATIO/CLASS PROPERTY RATIO/INHERITANCE RICHNESS/ATTRIBUTE RICHNESS")

# Inheritance Richness = average number of subclasses per class (source 227 - page 9) 
# Getting number of all subclasses
query_subclasses = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(*) AS ?numInheritanceRelations)
WHERE {
  # ?subclass rdfs:subClassOf ?superclass .
}
"""

num_subclasses = 0

res = g.query(query_subclasses)

for row in res:
  num_subclasses = int(row["numInheritanceRelations"])

# Getting number of datatype properties
query_datatype_properties_t = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(DISTINCT ?property) AS ?numDatatypeProperties)
WHERE {
  # ?property rdf:type owl:DatatypeProperty .
}
"""

num_datatype_properties_t = 0

res = g.query(query_datatype_properties_t)

for row in res:
  num_datatype_properties_t = int(row["numDatatypeProperties"])

debug_print("Number of Datatype properties in T-Box: " + str(num_datatype_properties_t))

# Datatype Properties in A-Box
query_datatype_properties_a = """
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT (COUNT(DISTINCT ?property) AS ?numDatatypeProperties)
WHERE {
  # ?s ?property ?o 
  Filter(isLiteral(?o))
}
"""

num_datatype_properties_a = 0

res = g.query(query_datatype_properties_a)

for row in res:
  num_datatype_properties_a = int(row["numDatatypeProperties"])

debug_print("Number of Datatype properties in A-Box: " + str(num_datatype_properties_a))

num_datatype_properties = num_datatype_properties_t + num_datatype_properties_a

debug_print("Number of Datatype properties: " + str(num_datatype_properties))

if num_classes > 0:
  prop_class_ratio = round(num_properties / num_classes, DEC_PLACES) 
  #print("-Property Class Ratio: " + str(prop_class_ratio))
else:
  # source 172 - page: assumes that classes must exist for properties to exist (Number of Properties, Number of CLasses > 1)
  # I assume: no classes -> ratio = 0
  prop_class_ratio = 0.0
  #print("-Property Class Ratio: 0")

# Class Property Ratio
if num_properties > 0:
  class_prop_ratio = round(num_classes / num_properties, DEC_PLACES) 
 # print("-Class Property Ratio: " + str(class_prop_ratio))
else:
  # metric is not defined for num_properties = 0
  # I assume: no properties -> ratio = 0
  class_prop_ratio = 0
  #print("-Class Property Ratio is INF!")

if num_classes > 0:
  inheritance_richness = round(num_subclasses / num_classes, DEC_PLACES) 
  #print("-Inheritance Richness: " + str(inheritance_richness))
else:
  # metric is not defined for num_classes = 0
  inheritance_richness = 0
  #print("-Inheritance Richness is INF!")

if num_classes > 0:
  attr_richness = round(num_datatype_properties / num_classes, DEC_PLACES)
  #print("-Attribute Richness: " + str(attr_richness))
else:
  # metric is not defined for num_classes = 0
  attr_richness = 0
  #print("-Attribute Richness is INF!")

print("FINISHED CALCULATING PROPERTY CLASS RATIO/CLASS PROPERTY RATIO/INHERITANCE RICHNESS/ATTRIBUTE RICHNESS")
print("\nRESULTS:")

print("-Property Class Ratio: " + str(prop_class_ratio))
print("-Class Property Ratio: " + str(class_prop_ratio))
print("-Inheritance Richness: " + str(inheritance_richness))
print("-Attribute Richness: " + str(attr_richness))
# Out:
# STARTING CALCULATING PROPERTY CLASS RATIO/CLASS PROPERTY RATIO/INHERITANCE RICHNESS/ATTRIBUTE RICHNESS
# Number of Datatype properties in T-Box: 2
# Number of Datatype properties in A-Box: 3
# Number of Datatype properties: 5
# FINISHED CALCULATING PROPERTY CLASS RATIO/CLASS PROPERTY RATIO/INHERITANCE RICHNESS/ATTRIBUTE RICHNESS
#
# RESULTS:
# -Property Class Ratio: 1.62
# -Class Property Ratio: 0.62
# -Inheritance Richness: 0.25
# -Attribute Richness: 0.62

# %%
print("STARTING CALCULATING AVERAGE CLASS CONNECTIVITY/AVERAGE POPULATION")

# Average Class Connectivity
# Connectivity of a class is defined as the total number of relationships instances of 
# the class have with instances of other classes (source 227 - page 10)

# looking for number of triples (c1, p, c2) or (c3, p, c1) for each class with instances c1
# c1, c2 are instances of classes 
# c1 != c2,c3
# property != rdf:type because we are not interested in the class relationships 
query_class_connectivity = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT ?class (COUNT(*) AS ?connectivity)
WHERE {
  {
    # ?instance ?property ?target .

    # ?instance rdf:type ?class .
    # ?target rdf:type ?targetClass .

    FILTER(?property != rdf:type)
    FILTER(?class != ?targetClass)
  }
  UNION
  {
    # ?instance ?property ?target .

    # ?target rdf:type ?class .
    # ?instance rdf:type ?targetClass .

    FILTER(?property != rdf:type)
    FILTER(?class != ?targetClass)
  }
}
GROUP BY ?class
"""

res = g.query(query_class_connectivity)

class_connectivity_list = []
sum_connectivities = 0

for row in res:
  class_name = row["class"]
  connectivity = int(row["connectivity"])
  class_connectivity_list.append((class_name, connectivity))
  sum_connectivities += connectivity

for class_name, connectivity in class_connectivity_list:
  debug_print("Connectivity of Class " + str(class_name) + ": " + str(connectivity))

if num_classes > 0:
  avg_class_connectivity = round(sum_connectivities / num_classes, DEC_PLACES)
  #print("-Average Class Connectivity: " + str(avg_class_connectivity))
else:
  # metric is not defined for num_classes = 0
  avg_class_connectivity = 0
  #print("-Average Class Connectivity is INF!")

# Average Population
if num_classes > 0:
  avg_population = round(num_instances / num_classes, DEC_PLACES)
  #print("-Average Population: " + str(avg_population))
else:
  # metric is not defined for num_classes = 0
  avg_population = 0
  #print("-Average Population is INF!")

print("FINISHED CALCULATING AVERAGE CLASS CONNECTIVITY/AVERAGE POPULATION")

print("\nRESULTS:")
print("-Average Class Connectivity: " + str(avg_class_connectivity))
print("-Average Population: " + str(avg_population))
# Out:
# STARTING CALCULATING AVERAGE CLASS CONNECTIVITY/AVERAGE POPULATION
# Connectivity of Class http://www.w3.org/2002/07/owl#ObjectProperty: 4
# Connectivity of Class http://www.w3.org/2002/07/owl#DatatypeProperty: 2
# Connectivity of Class http://example.org/ontology#Employee: 1
# Connectivity of Class http://example.org/ontology#Manager: 2
# Connectivity of Class http://www.w3.org/2002/07/owl#Class: 6
# Connectivity of Class http://example.org/ontology#Department: 3
# FINISHED CALCULATING AVERAGE CLASS CONNECTIVITY/AVERAGE POPULATION
#
# RESULTS:
# -Average Class Connectivity: 2.25
# -Average Population: 1.5

# %%
# TODO: Cohesion

# %%
# Average Class Connectivity
# Connectivity of a class is defined as the total number of relationships instances of 
# the class have with instances of other classes (source 227 - page 10)

# looking for number of triples (c1, p, c2) or (c3, p, c1) for each class with instances c1
# c1, c2, c3 are instances of classes 
# c1 != c2,c3
# property != rdf:type because we are not interested in the class relationships 
query_class_connectivity = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT ?class (COUNT(*) AS ?connectivity)
WHERE {
  {
    # ?instance ?property ?target .

    # ?instance rdf:type ?class .
    # ?target rdf:type ?targetClass .

    FILTER(?property != rdf:type)
    FILTER(?class != ?targetClass)
  }
  UNION
  {
    # ?instance ?property2 ?target .

    # ?target rdf:type ?class .
    # ?instance rdf:type ?targetClass .

    FILTER(?property != rdf:type)
    FILTER(?class2 != ?targetClass)
  }
}
GROUP BY ?class
"""

class_connectivity_list = []
sum_connectivities = 0

res = g.query(query_class_connectivity)

#for row in res:
 # print(str(row["class"]) + ": " + str(row["instance"]) + " - " + str(row["property"]) + " - " + str(row["target"]))

for row in res:
    class_name = row["class"]
    connectivity = int(row["connectivity"])
    class_connectivity_list.append((class_name, connectivity))
    sum_connectivities += connectivity


for class_name, connectivity in class_connectivity_list:
  debug_print("Connectivity of Class " + str(class_name) + ": " + str(connectivity))

if num_classes > 0:
  avg_class_connectivity = sum_connectivities / num_classes
  print("Average Class Connectivity: " + str(avg_class_connectivity))
else:
  print("Average Class Connectivity is INF!")
# Out:
# Connectivity of Class http://www.w3.org/2002/07/owl#ObjectProperty: 4
# Connectivity of Class http://www.w3.org/2002/07/owl#DatatypeProperty: 2
# Connectivity of Class http://example.org/ontology#Employee: 1
# Connectivity of Class http://example.org/ontology#Manager: 2
# Average Class Connectivity: 1.125
