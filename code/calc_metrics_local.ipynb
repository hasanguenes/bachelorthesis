# %%
from rdflib import Graph
from rdflib import RDF
from rdflib import URIRef
from rdflib import Literal
import networkx as nx
import matplotlib.pyplot as plt
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from queries import QUERY_AI, QUERY_FILM, QUERY_PERSON
from paths_to_examples import REPO_BOOKS, REPO_PEOPLE, WIKIDATA, GPT_EX, GPT_SUBCLASSES

DEBUG = True  # for debug prints
PRINTGRAPH = False # for showing the networkX graph
LOCAL = True # for choosing local ttl file path or SPARQL endpoint 

def debug_print(*args, **kwargs):
    if DEBUG:
        print(*args, **kwargs)


# printing all elements of a set
def print_set(set):
    if DEBUG:
        for i in set:
            print(str(i))

def show_graph(G):
    if PRINTGRAPH:
        # calculating positions for nodes
        pos = nx.spring_layout(G, k=0.5, iterations=50)

        # printing nodes and edges
        plt.figure(figsize=(12, 8))
        nx.draw(G, pos, with_labels=True, node_color="lightblue", node_size=1500, font_size=10, font_weight="bold", arrows=True)

        # printing labels for the edges
        edge_labels = nx.get_edge_attributes(G, 'label')
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

        plt.title("RDF Graph")
        plt.axis("off")
        plt.show()

        print("FINISHED PRINTING GRAPH\n\n")        

# Calculating all paths from one root node (start node)
def find_all_paths(G, start_node):
    # helper function for DFS
    def dfs(node, path):
        global num_paths
        global abs_depth
        global max_depth

        # skip node if it already is in path (avoiding cycles)
        if node in path:
            return
        
        # add current node to path
        path.append(node)
        
        neighbors = list(G.neighbors(node))
        # if node does not have any neighbors left, there is no other path left
        if not neighbors:
            paths.append(list(path))  # Store current path
            num_paths += 1
            abs_depth += (len(path) - 1) # cardinality of a path = number of EDGES in path (=> -1)
            if (len(path)-1) > max_depth:
                max_depth = len(path) - 1
        
        # recursively extend the path for each neighbor
        for neighbor in neighbors:
            dfs(neighbor, path)
        
        # remove node from the path to find next path
        path.pop()

    # list which stores all paths
    paths = []
    
    # starts DFS with start_node
    dfs(start_node, [])
    
    return paths

# %%
# path to ttl file
# can also be an online graph source
ttl_file_path = REPO_BOOKS
g = Graph()

print("STARTING PARSING")

# if it fails -> print some error
try:
    g.parse(ttl_file_path, format="turtle")
except Exception as e:
    print("ERROR WHILE PARSING GRAPH: {e}")    

print("Number of triples: " + str(len(g)))    
print("FINISHED PARSING\n")

#for s, p, o in g:
 #   print(s, p, o)

print("STARTING GETTING ROOT NODES AND LITERALS")

all_nodes = set(g.subjects())

# printing all subject nodes
# print_set(nodes)

# all objects
object_nodes = set(g.objects())

# all literals in a graph (literals can only appear as objects)
literals = set(o for o in object_nodes if isinstance(o, Literal))

# converting items of literals to strings
literals = {str(item) for item in literals}

# getting possible root nodes
root_nodes = all_nodes - object_nodes

debug_print("Root Nodes:")
print_set(root_nodes)
#debug_print("\n")

print("FINISHED GETTING ROOT NODES AND LITERALS\n")

print("STARTING CREATING GRAPH G")

# NetworkX-DiGraph for visualization
G = nx.DiGraph()

debug_print("Printing all triples:")
# add triples to GRaph G
for subj, pred, obj in g:
    G.add_edge(str(subj), str(obj), label=str(pred))
    #debug_print("(" , str(subj), ",", str(pred), ",", str(obj), ")")
    debug_print("(" , subj, ",", pred, ",", obj, ")")

print("FINISHED CREATING GRAPH G\n")

show_graph(G)

num_paths = 0
abs_depth = 0
max_depth = 0

print("STARTING CALCULATING PATHS")

# list of paths for all root nodes
all_paths = {}

# calculating all paths from root nodes
for root in list(root_nodes):
    str_root = str(root)
    debug_print("Starting searching for paths with root node: " + str_root)
    all_paths[str_root] = find_all_paths(G, str_root)

print("FINISHED CALCULATING PATHS\n")

# Output root node + found paths
# print("FOUND PATHS:")
# for root_node, paths in all_paths.items():
#     print(f"Root-Knoten: {root_node}")
#     for path in paths:
#         print(path)

# Output found paths
print("FOUND PATHS:")
for root_node, paths in all_paths.items():
    for path in paths:
        print(path)
        print("Path length = " + str(len(path)-1))
        

#num_paths = len(all_paths)

print("RESULTS:")

print("-Number of Paths: " + str(num_paths))
print("-Absolute depth: " + str(abs_depth))

avg_depth = abs_depth / num_paths

print("-Average depth: " + str(avg_depth))
print("-Maximal depth: " + str(max_depth))
# Out:
# STARTING PARSING
# Number of triples: 952
# FINISHED PARSING
#
# STARTING GETTING ROOT NODES AND LITERALS
# Root Nodes:
# http://example.org/ns#Node161
# http://example.org/ns#Node104
# http://example.org/ns#Node143
# http://example.org/ns#Node151
# http://example.org/ns#Node172
# http://example.org/ns#Node148
# http://example.org/ns#Node183
# http://example.org/ns#Node139
# http://example.org/ns#Node130
# http://example.org/ns#Node108
# http://example.org/ns#Node146
# http://example.org/ns#Node155
# http://example.org/ns#Node153
# http://example.org/ns#Node124
# http://example.org/ns#Node167
# http://example.org/ns#Node128
# http://example.org/ns#Node187
# http://example.org/ns#Node132
# http://example.org/ns#Node100
# http://example.org/ns#Node135
# http://example.org/ns#Node118
# http://example.org/ns#Node165
# http://example.org/ns#Node180
# http://example.org/ns#Node126
# http://example.org/ns#Node170
# http://example.org/ns#Node176
# http://example.org/ns#Node121
# http://example.org/ns#Node112
# http://example.org/ns#Node158
# http://example.org/ns#Node114
# FINISHED GETTING ROOT NODES AND LITERALS
#
# STARTING CREATING GRAPH G
# Printing all triples:
# ( http://example.org/ns#Node146 , http://schema.org/award , National Book Award )
# ( http://example.org/ns#Node146 , http://schema.org/award , National Book Award )
# ( http://example.org/ns#Node180 , http://schema.org/isbn , 312-2-69- )
# ( http://example.org/ns#Node180 , http://schema.org/isbn , 312-2-69- )
# ( http://example.org/ns#Node142 , http://schema.org/telephone , 671750-4296 )
# ( http://example.org/ns#Node142 , http://schema.org/telephone , 671750-4296 )
# ( http://example.org/ns#Node163 , http://schema.org/deathDate , 2013-07-07 )
# ( http://example.org/ns#Node163 , http://schema.org/deathDate , 2013-07-07 )
# ( http://example.org/ns#Node128 , http://schema.org/author , http://example.org/ns#Node129 )
# ( http://example.org/ns#Node128 , http://schema.org/author , http://example.org/ns#Node129 )
# ( http://example.org/ns#Node185 , http://schema.org/email , barrett_222@gmail.com )
# ( http://example.org/ns#Node185 , http://schema.org/email , barrett_222@gmail.com )
# ( http://example.org/ns#Node166 , http://schema.org/gender , female )
# ( http://example.org/ns#Node166 , http://schema.org/gender , female )
# ( http://example.org/ns#Node184 , http://schema.org/givenName , Christen )
# ( http://example.org/ns#Node184 , http://schema.org/givenName , Christen )
# ( http://example.org/ns#Node121 , http://schema.org/award , Hugo Award )
# ( http://example.org/ns#Node121 , http://schema.org/award , Hugo Award )
# ( http://example.org/ns#Node170 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node170 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node183 , http://schema.org/genre , Contemporary Fiction )
# ( http://example.org/ns#Node183 , http://schema.org/genre , Contemporary Fiction )
# ( http://example.org/ns#Node117 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node117 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node142 , http://schema.org/email , colin_204@gmail.com )
# ( http://example.org/ns#Node142 , http://schema.org/email , colin_204@gmail.com )
# ( http://example.org/ns#Node152 , http://schema.org/email , kerry_425@gmail.com )
# ( http://example.org/ns#Node152 , http://schema.org/email , kerry_425@gmail.com )
# ( http://example.org/ns#Node154 , http://schema.org/givenName , Daniela )
# ( http://example.org/ns#Node154 , http://schema.org/givenName , Daniela )
# ( http://example.org/ns#Node104 , http://schema.org/award , Hugo Award )
# ( http://example.org/ns#Node104 , http://schema.org/award , Hugo Award )
# ( http://example.org/ns#Node157 , http://schema.org/telephone , 048-707-18 )
# ( http://example.org/ns#Node157 , http://schema.org/telephone , 048-707-18 )
# ( http://example.org/ns#Node186 , http://schema.org/gender , male )
# ( http://example.org/ns#Node186 , http://schema.org/gender , male )
# ( http://example.org/ns#Node167 , http://schema.org/author , http://example.org/ns#Node168 )
# ( http://example.org/ns#Node167 , http://schema.org/author , http://example.org/ns#Node168 )
# ( http://example.org/ns#Node133 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node133 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node152 , http://schema.org/gender , male )
# ( http://example.org/ns#Node152 , http://schema.org/gender , male )
# ( http://example.org/ns#Node124 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node124 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node160 , http://schema.org/telephone , 121-077-4826433 )
# ( http://example.org/ns#Node160 , http://schema.org/telephone , 121-077-4826433 )
# ( http://example.org/ns#Node132 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node132 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node113 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node113 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node173 , http://schema.org/deathDate , 1975-07-07 )
# ( http://example.org/ns#Node173 , http://schema.org/deathDate , 1975-07-07 )
# ( http://example.org/ns#Node166 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node166 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node130 , http://schema.org/award , National Book Critics Circle Award )
# ( http://example.org/ns#Node130 , http://schema.org/award , National Book Critics Circle Award )
# ( http://example.org/ns#Node105 , http://schema.org/telephone , 703-902-50 )
# ( http://example.org/ns#Node105 , http://schema.org/telephone , 703-902-50 )
# ( http://example.org/ns#Node170 , http://schema.org/datePublished , 2010-07-07 )
# ( http://example.org/ns#Node170 , http://schema.org/datePublished , 2010-07-07 )
# ( http://example.org/ns#Node134 , http://schema.org/email , karna_600@gmail.com )
# ( http://example.org/ns#Node134 , http://schema.org/email , karna_600@gmail.com )
# ( http://example.org/ns#Node100 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node100 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node151 , http://schema.org/datePublished , 1980-07-07 )
# ( http://example.org/ns#Node151 , http://schema.org/datePublished , 1980-07-07 )
# ( http://example.org/ns#Node125 , http://schema.org/gender , female )
# ( http://example.org/ns#Node125 , http://schema.org/gender , female )
# ( http://example.org/ns#Node174 , http://schema.org/telephone , 442-278- )
# ( http://example.org/ns#Node174 , http://schema.org/telephone , 442-278- )
# ( http://example.org/ns#Node173 , http://schema.org/telephone , 982896-3757166- )
# ( http://example.org/ns#Node173 , http://schema.org/telephone , 982896-3757166- )
# ( http://example.org/ns#Node110 , http://schema.org/email , catarina_719@gmail.com )
# ( http://example.org/ns#Node110 , http://schema.org/email , catarina_719@gmail.com )
# ( http://example.org/ns#Node145 , http://schema.org/telephone , 862081-62562 )
# ( http://example.org/ns#Node145 , http://schema.org/telephone , 862081-62562 )
# ( http://example.org/ns#Node161 , http://schema.org/genre , Art and Photography )
# ( http://example.org/ns#Node161 , http://schema.org/genre , Art and Photography )
# ( http://example.org/ns#Node101 , http://schema.org/deathDate , 2019-07-07 )
# ( http://example.org/ns#Node101 , http://schema.org/deathDate , 2019-07-07 )
# ( http://example.org/ns#Node151 , http://schema.org/isbn , 885-1-99-7 )
# ( http://example.org/ns#Node151 , http://schema.org/isbn , 885-1-99-7 )
# ( http://example.org/ns#Node140 , http://schema.org/email , odessa_552@gmail.com )
# ( http://example.org/ns#Node140 , http://schema.org/email , odessa_552@gmail.com )
# ( http://example.org/ns#Node169 , http://schema.org/givenName , Tabbie )
# ( http://example.org/ns#Node169 , http://schema.org/givenName , Tabbie )
# ( http://example.org/ns#Node181 , http://schema.org/email , emory_176@gmail.com )
# ( http://example.org/ns#Node181 , http://schema.org/email , emory_176@gmail.com )
# ( http://example.org/ns#Node162 , http://schema.org/email , ralina_366@gmail.com )
# ( http://example.org/ns#Node162 , http://schema.org/email , ralina_366@gmail.com )
# ( http://example.org/ns#Node114 , http://schema.org/numberOfPages , 132 )
# ( http://example.org/ns#Node114 , http://schema.org/numberOfPages , 132 )
# ( http://example.org/ns#Node104 , http://schema.org/name , Satan's Tail (Dreamland  #7) )
# ( http://example.org/ns#Node104 , http://schema.org/name , Satan's Tail (Dreamland  #7) )
# ( http://example.org/ns#Node183 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node183 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node163 , http://schema.org/givenName , Oriana )
# ( http://example.org/ns#Node163 , http://schema.org/givenName , Oriana )
# ( http://example.org/ns#Node104 , http://schema.org/datePublished , 2011-07-07 )
# ( http://example.org/ns#Node104 , http://schema.org/datePublished , 2011-07-07 )
# ( http://example.org/ns#Node126 , http://schema.org/bookEdition , http://schema.org/GraphicNovel )
# ( http://example.org/ns#Node126 , http://schema.org/bookEdition , http://schema.org/GraphicNovel )
# ( http://example.org/ns#Node139 , http://schema.org/author , http://example.org/ns#Node141 )
# ( http://example.org/ns#Node139 , http://schema.org/author , http://example.org/ns#Node141 )
# ( http://example.org/ns#Node158 , http://schema.org/datePublished , 2009-07-07 )
# ( http://example.org/ns#Node158 , http://schema.org/datePublished , 2009-07-07 )
# ( http://example.org/ns#Node160 , http://schema.org/gender , female )
# ( http://example.org/ns#Node160 , http://schema.org/gender , female )
# ( http://example.org/ns#Node121 , http://schema.org/datePublished , 2002-07-07 )
# ( http://example.org/ns#Node121 , http://schema.org/datePublished , 2002-07-07 )
# ( http://example.org/ns#Node150 , http://schema.org/email , samantha_453@gmail.com )
# ( http://example.org/ns#Node150 , http://schema.org/email , samantha_453@gmail.com )
# ( http://example.org/ns#Node181 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node181 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node186 , http://schema.org/email , rick_450@gmail.com )
# ( http://example.org/ns#Node186 , http://schema.org/email , rick_450@gmail.com )
# ( http://example.org/ns#Node176 , http://schema.org/numberOfPages , 120 )
# ( http://example.org/ns#Node176 , http://schema.org/numberOfPages , 120 )
# ( http://example.org/ns#Node110 , http://schema.org/gender , female )
# ( http://example.org/ns#Node110 , http://schema.org/gender , female )
# ( http://example.org/ns#Node149 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node149 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node140 , http://schema.org/gender , female )
# ( http://example.org/ns#Node140 , http://schema.org/gender , female )
# ( http://example.org/ns#Node127 , http://schema.org/telephone , 862912-41 )
# ( http://example.org/ns#Node127 , http://schema.org/telephone , 862912-41 )
# ( http://example.org/ns#Node184 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node184 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node146 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node146 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node153 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node153 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node135 , http://schema.org/genre , Contemporary Fiction )
# ( http://example.org/ns#Node135 , http://schema.org/genre , Contemporary Fiction )
# ( http://example.org/ns#Node155 , http://schema.org/identifier , toik8124 )
# ( http://example.org/ns#Node155 , http://schema.org/identifier , toik8124 )
# ( http://example.org/ns#Node144 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node144 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node133 , http://schema.org/email , brunhilde_387@gmail.com )
# ( http://example.org/ns#Node133 , http://schema.org/email , brunhilde_387@gmail.com )
# ( http://example.org/ns#Node171 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node171 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node108 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node108 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node158 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node158 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node128 , http://schema.org/name , The Demon Princes  Volume One: The Star King  The Killing Machine  The Palace of Love )
# ( http://example.org/ns#Node128 , http://schema.org/name , The Demon Princes  Volume One: The Star King  The Killing Machine  The Palace of Love )
# ( http://example.org/ns#Node131 , http://schema.org/gender , female )
# ( http://example.org/ns#Node131 , http://schema.org/gender , female )
# ( http://example.org/ns#Node121 , http://schema.org/genre , Religion and Spirituality )
# ( http://example.org/ns#Node121 , http://schema.org/genre , Religion and Spirituality )
# ( http://example.org/ns#Node149 , http://schema.org/email , dyanna_399@gmail.com )
# ( http://example.org/ns#Node149 , http://schema.org/email , dyanna_399@gmail.com )
# ( http://example.org/ns#Node110 , http://schema.org/birthDate , 1987-07-07 )
# ( http://example.org/ns#Node110 , http://schema.org/birthDate , 1987-07-07 )
# ( http://example.org/ns#Node108 , http://schema.org/award , The Giller Prize )
# ( http://example.org/ns#Node108 , http://schema.org/award , The Giller Prize )
# ( http://example.org/ns#Node128 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node128 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node100 , http://schema.org/name , Cliffs Notes on Woolf's Mrs. Dalloway )
# ( http://example.org/ns#Node100 , http://schema.org/name , Cliffs Notes on Woolf's Mrs. Dalloway )
# ( http://example.org/ns#Node124 , http://schema.org/award , Caldecott Medal )
# ( http://example.org/ns#Node124 , http://schema.org/award , Caldecott Medal )
# ( http://example.org/ns#Node176 , http://schema.org/isbn , 331-0-66-32 )
# ( http://example.org/ns#Node176 , http://schema.org/isbn , 331-0-66-32 )
# ( http://example.org/ns#Node148 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node148 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node153 , http://schema.org/genre , Cyberpunk )
# ( http://example.org/ns#Node153 , http://schema.org/genre , Cyberpunk )
# ( http://example.org/ns#Node187 , http://schema.org/award , National Book Critics Circle Award )
# ( http://example.org/ns#Node187 , http://schema.org/award , National Book Critics Circle Award )
# ( http://example.org/ns#Node176 , http://schema.org/dateCreated , 1930-07-07 )
# ( http://example.org/ns#Node176 , http://schema.org/dateCreated , 1930-07-07 )
# ( http://example.org/ns#Node114 , http://schema.org/genre , Philosophical Fiction )
# ( http://example.org/ns#Node114 , http://schema.org/genre , Philosophical Fiction )
# ( http://example.org/ns#Node171 , http://schema.org/birthDate , 1991-07-07 )
# ( http://example.org/ns#Node171 , http://schema.org/birthDate , 1991-07-07 )
# ( http://example.org/ns#Node123 , http://schema.org/deathDate , 2003-07-07 )
# ( http://example.org/ns#Node123 , http://schema.org/deathDate , 2003-07-07 )
# ( http://example.org/ns#Node155 , http://schema.org/bookEdition , http://schema.org/Hardcover )
# ( http://example.org/ns#Node155 , http://schema.org/bookEdition , http://schema.org/Hardcover )
# ( http://example.org/ns#Node143 , http://schema.org/author , http://example.org/ns#Node144 )
# ( http://example.org/ns#Node143 , http://schema.org/author , http://example.org/ns#Node144 )
# ( http://example.org/ns#Node146 , http://schema.org/genre , Biography and Autobiography )
# ( http://example.org/ns#Node146 , http://schema.org/genre , Biography and Autobiography )
# ( http://example.org/ns#Node126 , http://schema.org/dateCreated , 1982-07-07 )
# ( http://example.org/ns#Node126 , http://schema.org/dateCreated , 1982-07-07 )
# ( http://example.org/ns#Node128 , http://schema.org/genre , Nature Writing )
# ( http://example.org/ns#Node128 , http://schema.org/genre , Nature Writing )
# ( http://example.org/ns#Node142 , http://schema.org/givenName , Colin )
# ( http://example.org/ns#Node142 , http://schema.org/givenName , Colin )
# ( http://example.org/ns#Node135 , http://schema.org/dateCreated , 1935-07-07 )
# ( http://example.org/ns#Node135 , http://schema.org/dateCreated , 1935-07-07 )
# ( http://example.org/ns#Node159 , http://schema.org/deathDate , 2008-07-07 )
# ( http://example.org/ns#Node159 , http://schema.org/deathDate , 2008-07-07 )
# ( http://example.org/ns#Node121 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node121 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node108 , http://schema.org/identifier , emze6815f )
# ( http://example.org/ns#Node108 , http://schema.org/identifier , emze6815f )
# ( http://example.org/ns#Node177 , http://schema.org/telephone , 761-966-723 )
# ( http://example.org/ns#Node177 , http://schema.org/telephone , 761-966-723 )
# ( http://example.org/ns#Node140 , http://schema.org/givenName , Odessa )
# ( http://example.org/ns#Node140 , http://schema.org/givenName , Odessa )
# ( http://example.org/ns#Node145 , http://schema.org/birthDate , 1989-07-07 )
# ( http://example.org/ns#Node145 , http://schema.org/birthDate , 1989-07-07 )
# ( http://example.org/ns#Node175 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node175 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node108 , http://schema.org/dateCreated , 1969-07-07 )
# ( http://example.org/ns#Node108 , http://schema.org/dateCreated , 1969-07-07 )
# ( http://example.org/ns#Node159 , http://schema.org/birthDate , 1979-07-07 )
# ( http://example.org/ns#Node159 , http://schema.org/birthDate , 1979-07-07 )
# ( http://example.org/ns#Node185 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node185 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node100 , http://schema.org/genre , Science Fiction Fantasy )
# ( http://example.org/ns#Node100 , http://schema.org/genre , Science Fiction Fantasy )
# ( http://example.org/ns#Node123 , http://schema.org/birthDate , 1961-07-07 )
# ( http://example.org/ns#Node123 , http://schema.org/birthDate , 1961-07-07 )
# ( http://example.org/ns#Node102 , http://schema.org/email , stig_965@gmail.com )
# ( http://example.org/ns#Node102 , http://schema.org/email , stig_965@gmail.com )
# ( http://example.org/ns#Node127 , http://schema.org/givenName , Georgette )
# ( http://example.org/ns#Node127 , http://schema.org/givenName , Georgette )
# ( http://example.org/ns#Node117 , http://schema.org/birthDate , 1952-07-07 )
# ( http://example.org/ns#Node117 , http://schema.org/birthDate , 1952-07-07 )
# ( http://example.org/ns#Node139 , http://schema.org/award , The Agatha Awards )
# ( http://example.org/ns#Node139 , http://schema.org/award , The Agatha Awards )
# ( http://example.org/ns#Node100 , http://schema.org/genre , Hard Science Fiction )
# ( http://example.org/ns#Node100 , http://schema.org/genre , Hard Science Fiction )
# ( http://example.org/ns#Node130 , http://schema.org/numberOfPages , 102 )
# ( http://example.org/ns#Node130 , http://schema.org/numberOfPages , 102 )
# ( http://example.org/ns#Node111 , http://schema.org/email , diana_753@gmail.com )
# ( http://example.org/ns#Node111 , http://schema.org/email , diana_753@gmail.com )
# ( http://example.org/ns#Node121 , http://schema.org/dateCreated , 1978-07-07 )
# ( http://example.org/ns#Node121 , http://schema.org/dateCreated , 1978-07-07 )
# ( http://example.org/ns#Node121 , http://schema.org/author , http://example.org/ns#Node122 )
# ( http://example.org/ns#Node121 , http://schema.org/author , http://example.org/ns#Node122 )
# ( http://example.org/ns#Node178 , http://schema.org/gender , male )
# ( http://example.org/ns#Node178 , http://schema.org/gender , male )
# ( http://example.org/ns#Node187 , http://schema.org/genre , European Literature )
# ( http://example.org/ns#Node187 , http://schema.org/genre , European Literature )
# ( http://example.org/ns#Node150 , http://schema.org/gender , female )
# ( http://example.org/ns#Node150 , http://schema.org/gender , female )
# ( http://example.org/ns#Node163 , http://schema.org/birthDate , 1995-07-07 )
# ( http://example.org/ns#Node163 , http://schema.org/birthDate , 1995-07-07 )
# ( http://example.org/ns#Node180 , http://schema.org/bookEdition , http://schema.org/Paperback )
# ( http://example.org/ns#Node180 , http://schema.org/bookEdition , http://schema.org/Paperback )
# ( http://example.org/ns#Node173 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node173 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node130 , http://schema.org/bookEdition , http://schema.org/Paperback )
# ( http://example.org/ns#Node130 , http://schema.org/bookEdition , http://schema.org/Paperback )
# ( http://example.org/ns#Node172 , http://schema.org/genre , Experimental Fiction )
# ( http://example.org/ns#Node172 , http://schema.org/genre , Experimental Fiction )
# ( http://example.org/ns#Node143 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node143 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node163 , http://schema.org/email , oriana_732@gmail.com )
# ( http://example.org/ns#Node163 , http://schema.org/email , oriana_732@gmail.com )
# ( http://example.org/ns#Node140 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node140 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node181 , http://schema.org/deathDate , 1986-07-07 )
# ( http://example.org/ns#Node181 , http://schema.org/deathDate , 1986-07-07 )
# ( http://example.org/ns#Node156 , http://schema.org/givenName , Gigi )
# ( http://example.org/ns#Node156 , http://schema.org/givenName , Gigi )
# ( http://example.org/ns#Node111 , http://schema.org/givenName , Diana )
# ( http://example.org/ns#Node111 , http://schema.org/givenName , Diana )
# ( http://example.org/ns#Node176 , http://schema.org/datePublished , 1979-07-07 )
# ( http://example.org/ns#Node176 , http://schema.org/datePublished , 1979-07-07 )
# ( http://example.org/ns#Node132 , http://schema.org/genre , Chick Lit )
# ( http://example.org/ns#Node132 , http://schema.org/genre , Chick Lit )
# ( http://example.org/ns#Node115 , http://schema.org/deathDate , 2000-07-07 )
# ( http://example.org/ns#Node115 , http://schema.org/deathDate , 2000-07-07 )
# ( http://example.org/ns#Node138 , http://schema.org/deathDate , 2002-07-07 )
# ( http://example.org/ns#Node138 , http://schema.org/deathDate , 2002-07-07 )
# ( http://example.org/ns#Node155 , http://schema.org/genre , Biography and Autobiography )
# ( http://example.org/ns#Node155 , http://schema.org/genre , Biography and Autobiography )
# ( http://example.org/ns#Node111 , http://schema.org/birthDate , 1980-07-07 )
# ( http://example.org/ns#Node111 , http://schema.org/birthDate , 1980-07-07 )
# ( http://example.org/ns#Node183 , http://schema.org/identifier , vmph2673h )
# ( http://example.org/ns#Node183 , http://schema.org/identifier , vmph2673h )
# ( http://example.org/ns#Node157 , http://schema.org/email , zane_515@gmail.com )
# ( http://example.org/ns#Node157 , http://schema.org/email , zane_515@gmail.com )
# ( http://example.org/ns#Node128 , http://schema.org/identifier , jodt7334 )
# ( http://example.org/ns#Node128 , http://schema.org/identifier , jodt7334 )
# ( http://example.org/ns#Node175 , http://schema.org/email , angel_935@gmail.com )
# ( http://example.org/ns#Node175 , http://schema.org/email , angel_935@gmail.com )
# ( http://example.org/ns#Node101 , http://schema.org/gender , female )
# ( http://example.org/ns#Node101 , http://schema.org/gender , female )
# ( http://example.org/ns#Node176 , http://schema.org/genre , African Literature )
# ( http://example.org/ns#Node176 , http://schema.org/genre , African Literature )
# ( http://example.org/ns#Node131 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node131 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node135 , http://schema.org/award , The Bram Stoker Awards )
# ( http://example.org/ns#Node135 , http://schema.org/award , The Bram Stoker Awards )
# ( http://example.org/ns#Node126 , http://schema.org/isbn , 650-8-05-6 )
# ( http://example.org/ns#Node126 , http://schema.org/isbn , 650-8-05-6 )
# ( http://example.org/ns#Node130 , http://schema.org/genre , Soft Science Fiction )
# ( http://example.org/ns#Node130 , http://schema.org/genre , Soft Science Fiction )
# ( http://example.org/ns#Node129 , http://schema.org/gender , male )
# ( http://example.org/ns#Node129 , http://schema.org/gender , male )
# ( http://example.org/ns#Node103 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node103 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node166 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node166 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node160 , http://schema.org/givenName , Fernanda )
# ( http://example.org/ns#Node160 , http://schema.org/givenName , Fernanda )
# ( http://example.org/ns#Node111 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node111 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node142 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node142 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node171 , http://schema.org/email , ira_913@gmail.com )
# ( http://example.org/ns#Node171 , http://schema.org/email , ira_913@gmail.com )
# ( http://example.org/ns#Node170 , http://schema.org/bookEdition , http://schema.org/EBook )
# ( http://example.org/ns#Node170 , http://schema.org/bookEdition , http://schema.org/EBook )
# ( http://example.org/ns#Node108 , http://schema.org/numberOfPages , 140 )
# ( http://example.org/ns#Node108 , http://schema.org/numberOfPages , 140 )
# ( http://example.org/ns#Node141 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node141 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node104 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node104 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node172 , http://schema.org/dateCreated , 1979-07-07 )
# ( http://example.org/ns#Node172 , http://schema.org/dateCreated , 1979-07-07 )
# ( http://example.org/ns#Node130 , http://schema.org/datePublished , 1984-07-07 )
# ( http://example.org/ns#Node130 , http://schema.org/datePublished , 1984-07-07 )
# ( http://example.org/ns#Node114 , http://schema.org/author , http://example.org/ns#Node115 )
# ( http://example.org/ns#Node114 , http://schema.org/author , http://example.org/ns#Node115 )
# ( http://example.org/ns#Node161 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node161 , http://schema.org/inLanguage , en-USA )
# ( http://example.org/ns#Node124 , http://schema.org/numberOfPages , 109 )
# ( http://example.org/ns#Node124 , http://schema.org/numberOfPages , 109 )
# ( http://example.org/ns#Node167 , http://schema.org/isbn , 405-3-68-19432 )
# ( http://example.org/ns#Node167 , http://schema.org/isbn , 405-3-68-19432 )
# ( http://example.org/ns#Node180 , http://schema.org/award , The Giller Prize )
# ( http://example.org/ns#Node180 , http://schema.org/award , The Giller Prize )
# ( http://example.org/ns#Node126 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node126 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node169 , http://schema.org/telephone , 756-382-081474 )
# ( http://example.org/ns#Node169 , http://schema.org/telephone , 756-382-081474 )
# ( http://example.org/ns#Node104 , http://schema.org/author , http://example.org/ns#Node105 )
# ( http://example.org/ns#Node104 , http://schema.org/author , http://example.org/ns#Node105 )
# ( http://example.org/ns#Node135 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node135 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node161 , http://schema.org/author , http://example.org/ns#Node163 )
# ( http://example.org/ns#Node161 , http://schema.org/author , http://example.org/ns#Node163 )
# ( http://example.org/ns#Node136 , http://schema.org/deathDate , 1975-07-07 )
# ( http://example.org/ns#Node136 , http://schema.org/deathDate , 1975-07-07 )
# ( http://example.org/ns#Node172 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node172 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node127 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node127 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node123 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node123 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node151 , http://schema.org/numberOfPages , 130 )
# ( http://example.org/ns#Node151 , http://schema.org/numberOfPages , 130 )
# ( http://example.org/ns#Node184 , http://schema.org/birthDate , 1994-07-07 )
# ( http://example.org/ns#Node184 , http://schema.org/birthDate , 1994-07-07 )
# ( http://example.org/ns#Node110 , http://schema.org/telephone , 659-751-64 )
# ( http://example.org/ns#Node110 , http://schema.org/telephone , 659-751-64 )
# ( http://example.org/ns#Node104 , http://schema.org/numberOfPages , 145 )
# ( http://example.org/ns#Node104 , http://schema.org/numberOfPages , 145 )
# ( http://example.org/ns#Node112 , http://schema.org/genre , Cookbook )
# ( http://example.org/ns#Node112 , http://schema.org/genre , Cookbook )
# ( http://example.org/ns#Node167 , http://schema.org/identifier , litl7809r )
# ( http://example.org/ns#Node167 , http://schema.org/identifier , litl7809r )
# ( http://example.org/ns#Node128 , http://schema.org/genre , Culinary Arts )
# ( http://example.org/ns#Node128 , http://schema.org/genre , Culinary Arts )
# ( http://example.org/ns#Node126 , http://schema.org/author , http://example.org/ns#Node127 )
# ( http://example.org/ns#Node126 , http://schema.org/author , http://example.org/ns#Node127 )
# ( http://example.org/ns#Node146 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node146 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node143 , http://schema.org/dateCreated , 1980-07-07 )
# ( http://example.org/ns#Node143 , http://schema.org/dateCreated , 1980-07-07 )
# ( http://example.org/ns#Node109 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node109 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node180 , http://schema.org/dateCreated , 1970-07-07 )
# ( http://example.org/ns#Node180 , http://schema.org/dateCreated , 1970-07-07 )
# ( http://example.org/ns#Node111 , http://schema.org/telephone , 761-053- )
# ( http://example.org/ns#Node111 , http://schema.org/telephone , 761-053- )
# ( http://example.org/ns#Node150 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node150 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node168 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node168 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node186 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node186 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node132 , http://schema.org/genre , Fable and Allegory )
# ( http://example.org/ns#Node132 , http://schema.org/genre , Fable and Allegory )
# ( http://example.org/ns#Node152 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node152 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node184 , http://schema.org/deathDate , 2011-07-07 )
# ( http://example.org/ns#Node184 , http://schema.org/deathDate , 2011-07-07 )
# ( http://example.org/ns#Node144 , http://schema.org/gender , male )
# ( http://example.org/ns#Node144 , http://schema.org/gender , male )
# ( http://example.org/ns#Node171 , http://schema.org/gender , male )
# ( http://example.org/ns#Node171 , http://schema.org/gender , male )
# ( http://example.org/ns#Node172 , http://schema.org/author , http://example.org/ns#Node173 )
# ( http://example.org/ns#Node172 , http://schema.org/author , http://example.org/ns#Node173 )
# ( http://example.org/ns#Node123 , http://schema.org/givenName , Aldus )
# ( http://example.org/ns#Node123 , http://schema.org/givenName , Aldus )
# ( http://example.org/ns#Node188 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node188 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node104 , http://schema.org/genre , Reference )
# ( http://example.org/ns#Node104 , http://schema.org/genre , Reference )
# ( http://example.org/ns#Node187 , http://schema.org/identifier , xqyh4802kg )
# ( http://example.org/ns#Node187 , http://schema.org/identifier , xqyh4802kg )
# ( http://example.org/ns#Node180 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node180 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node136 , http://schema.org/gender , female )
# ( http://example.org/ns#Node136 , http://schema.org/gender , female )
# ( http://example.org/ns#Node166 , http://schema.org/email , glory_410@gmail.com )
# ( http://example.org/ns#Node166 , http://schema.org/email , glory_410@gmail.com )
# ( http://example.org/ns#Node117 , http://schema.org/gender , male )
# ( http://example.org/ns#Node117 , http://schema.org/gender , male )
# ( http://example.org/ns#Node108 , http://schema.org/genre , Travel Memoir )
# ( http://example.org/ns#Node108 , http://schema.org/genre , Travel Memoir )
# ( http://example.org/ns#Node100 , http://schema.org/author , http://example.org/ns#Node103 )
# ( http://example.org/ns#Node100 , http://schema.org/author , http://example.org/ns#Node103 )
# ( http://example.org/ns#Node144 , http://schema.org/deathDate , 2009-07-07 )
# ( http://example.org/ns#Node144 , http://schema.org/deathDate , 2009-07-07 )
# ( http://example.org/ns#Node130 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node130 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node151 , http://schema.org/bookEdition , http://schema.org/Hardcover )
# ( http://example.org/ns#Node151 , http://schema.org/bookEdition , http://schema.org/Hardcover )
# ( http://example.org/ns#Node134 , http://schema.org/deathDate , 1992-07-07 )
# ( http://example.org/ns#Node134 , http://schema.org/deathDate , 1992-07-07 )
# ( http://example.org/ns#Node134 , http://schema.org/telephone , 515979-292 )
# ( http://example.org/ns#Node134 , http://schema.org/telephone , 515979-292 )
# ( http://example.org/ns#Node108 , http://schema.org/genre , Hard Science Fiction )
# ( http://example.org/ns#Node108 , http://schema.org/genre , Hard Science Fiction )
# ( http://example.org/ns#Node165 , http://schema.org/genre , DIY and Crafts )
# ( http://example.org/ns#Node165 , http://schema.org/genre , DIY and Crafts )
# ( http://example.org/ns#Node139 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node139 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node101 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node101 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node187 , http://schema.org/genre , Fairy Tale )
# ( http://example.org/ns#Node187 , http://schema.org/genre , Fairy Tale )
# ( http://example.org/ns#Node128 , http://schema.org/bookEdition , http://schema.org/EBook )
# ( http://example.org/ns#Node128 , http://schema.org/bookEdition , http://schema.org/EBook )
# ( http://example.org/ns#Node113 , http://schema.org/gender , male )
# ( http://example.org/ns#Node113 , http://schema.org/gender , male )
# ( http://example.org/ns#Node117 , http://schema.org/givenName , Aron )
# ( http://example.org/ns#Node117 , http://schema.org/givenName , Aron )
# ( http://example.org/ns#Node127 , http://schema.org/email , georgette_413@gmail.com )
# ( http://example.org/ns#Node127 , http://schema.org/email , georgette_413@gmail.com )
# ( http://example.org/ns#Node187 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node187 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node125 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node125 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node167 , http://schema.org/author , http://example.org/ns#Node169 )
# ( http://example.org/ns#Node167 , http://schema.org/author , http://example.org/ns#Node169 )
# ( http://example.org/ns#Node118 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node118 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node176 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node176 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node158 , http://schema.org/name , The Natural Way to Draw )
# ( http://example.org/ns#Node158 , http://schema.org/name , The Natural Way to Draw )
# ( http://example.org/ns#Node155 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node155 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Book )
# ( http://example.org/ns#Node101 , http://schema.org/givenName , Vivie )
# ( http://example.org/ns#Node101 , http://schema.org/givenName , Vivie )
# ( http://example.org/ns#Node175 , http://schema.org/birthDate , 1990-07-07 )
# ( http://example.org/ns#Node175 , http://schema.org/birthDate , 1990-07-07 )
# ( http://example.org/ns#Node155 , http://schema.org/numberOfPages , 100 )
# ( http://example.org/ns#Node155 , http://schema.org/numberOfPages , 100 )
# ( http://example.org/ns#Node100 , http://schema.org/author , http://example.org/ns#Node102 )
# ( http://example.org/ns#Node100 , http://schema.org/author , http://example.org/ns#Node102 )
# ( http://example.org/ns#Node175 , http://schema.org/gender , male )
# ( http://example.org/ns#Node175 , http://schema.org/gender , male )
# ( http://example.org/ns#Node108 , http://schema.org/datePublished , 1985-07-07 )
# ( http://example.org/ns#Node108 , http://schema.org/datePublished , 1985-07-07 )
# ( http://example.org/ns#Node183 , http://schema.org/genre , Military Memoir )
# ( http://example.org/ns#Node183 , http://schema.org/genre , Military Memoir )
# ( http://example.org/ns#Node139 , http://schema.org/name , A Room with a View / Howards End )
# ( http://example.org/ns#Node139 , http://schema.org/name , A Room with a View / Howards End )
# ( http://example.org/ns#Node180 , http://schema.org/identifier , mmsm7710b )
# ( http://example.org/ns#Node180 , http://schema.org/identifier , mmsm7710b )
# ( http://example.org/ns#Node183 , http://schema.org/name , The Winds of War (The Henry Family  #1) )
# ( http://example.org/ns#Node183 , http://schema.org/name , The Winds of War (The Henry Family  #1) )
# ( http://example.org/ns#Node161 , http://schema.org/genre , Motivational and Inspirational )
# ( http://example.org/ns#Node161 , http://schema.org/genre , Motivational and Inspirational )
# ( http://example.org/ns#Node106 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node106 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node108 , http://schema.org/author , http://example.org/ns#Node109 )
# ( http://example.org/ns#Node108 , http://schema.org/author , http://example.org/ns#Node109 )
# ( http://example.org/ns#Node160 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node160 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node162 , http://schema.org/givenName , Ralina )
# ( http://example.org/ns#Node162 , http://schema.org/givenName , Ralina )
# ( http://example.org/ns#Node141 , http://schema.org/telephone , 297400-76815099 )
# ( http://example.org/ns#Node141 , http://schema.org/telephone , 297400-76815099 )
# ( http://example.org/ns#Node135 , http://schema.org/genre , Drama )
# ( http://example.org/ns#Node135 , http://schema.org/genre , Drama )
# ( http://example.org/ns#Node173 , http://schema.org/gender , male )
# ( http://example.org/ns#Node173 , http://schema.org/gender , male )
# ( http://example.org/ns#Node124 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node124 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node148 , http://schema.org/bookEdition , http://schema.org/Hardcover )
# ( http://example.org/ns#Node148 , http://schema.org/bookEdition , http://schema.org/Hardcover )
# ( http://example.org/ns#Node102 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node102 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node137 , http://schema.org/deathDate , 1995-07-07 )
# ( http://example.org/ns#Node137 , http://schema.org/deathDate , 1995-07-07 )
# ( http://example.org/ns#Node177 , http://schema.org/deathDate , 1974-07-07 )
# ( http://example.org/ns#Node177 , http://schema.org/deathDate , 1974-07-07 )
# ( http://example.org/ns#Node140 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node140 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node165 , http://schema.org/name , The Lilac Bus )
# ( http://example.org/ns#Node165 , http://schema.org/name , The Lilac Bus )
# ( http://example.org/ns#Node167 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node167 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node108 , http://schema.org/genre , Urban Fantasy )
# ( http://example.org/ns#Node108 , http://schema.org/genre , Urban Fantasy )
# ( http://example.org/ns#Node164 , http://schema.org/givenName , Parwane )
# ( http://example.org/ns#Node164 , http://schema.org/givenName , Parwane )
# ( http://example.org/ns#Node100 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node100 , http://schema.org/inLanguage , en-UK )
# ( http://example.org/ns#Node165 , http://schema.org/numberOfPages , 111 )
# ( http://example.org/ns#Node165 , http://schema.org/numberOfPages , 111 )
# ( http://example.org/ns#Node119 , http://schema.org/email , blaire_912@gmail.com )
# ( http://example.org/ns#Node119 , http://schema.org/email , blaire_912@gmail.com )
# ( http://example.org/ns#Node177 , http://schema.org/givenName , Collins )
# ( http://example.org/ns#Node177 , http://schema.org/givenName , Collins )
# ( http://example.org/ns#Node132 , http://schema.org/bookEdition , http://schema.org/GraphicNovel )
# ( http://example.org/ns#Node132 , http://schema.org/bookEdition , http://schema.org/GraphicNovel )
# ( http://example.org/ns#Node188 , http://schema.org/telephone , 606-610-5786 )
# ( http://example.org/ns#Node188 , http://schema.org/telephone , 606-610-5786 )
# ( http://example.org/ns#Node152 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node152 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node114 , http://schema.org/genre , Business and Economics )
# ( http://example.org/ns#Node114 , http://schema.org/genre , Business and Economics )
# ( http://example.org/ns#Node112 , http://schema.org/award , National Book Critics Circle Award )
# ( http://example.org/ns#Node112 , http://schema.org/award , National Book Critics Circle Award )
# ( http://example.org/ns#Node151 , http://schema.org/author , http://example.org/ns#Node152 )
# ( http://example.org/ns#Node151 , http://schema.org/author , http://example.org/ns#Node152 )
# ( http://example.org/ns#Node116 , http://schema.org/birthDate , 1965-07-07 )
# ( http://example.org/ns#Node116 , http://schema.org/birthDate , 1965-07-07 )
# ( http://example.org/ns#Node136 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node136 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ( http://example.org/ns#Node169 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node169 , http://www.w3.org/1999/02/22-rdf-syntax-ns#type , http://schema.org/Person )
# ( http://example.org/ns#Node118 , http://schema.org/genre , Culinary Arts )
# ( http://example.org/ns#Node118 , http://schema.org/genre , Culinary Arts )
# ( http://example.org/ns#Node167 , http://schema.org/datePublished , 1995-07-07 )
# ( http://example.org/ns#Node167 , http://schema.org/datePublished , 1995-07-07 )
# ( http://example.org/ns#Node118 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node118 , http://www.w3.org/ns/shacl#description , http://schema.org/BookShape )
# ( http://example.org/ns#Node103 , http://schema.org/gender , male )
# ( http://example.org/ns#Node103 , http://schema.org/gender , male )
# ( http://example.org/ns#Node145 , http://www.w3.org/ns/shacl#description , http://schema.org/AuthorShape )
# ...
# Path length = 1
# ['http://example.org/ns#Node126', 'Hugo Award']
# Path length = 1
# ['http://example.org/ns#Node126', 'qgmy3231fo']
# Path length = 1
# ['http://example.org/ns#Node126', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node126', 'Science']
# Path length = 1
# ['http://example.org/ns#Node170', 'en-UK']
# Path length = 1
# ['http://example.org/ns#Node170', '2010-07-07']
# Path length = 1
# ['http://example.org/ns#Node170', 'http://schema.org/EBook']
# Path length = 1
# ['http://example.org/ns#Node170', 'Legal Fiction']
# Path length = 1
# ['http://example.org/ns#Node170', '147']
# Path length = 1
# ['http://example.org/ns#Node170', 'Biography']
# Path length = 1
# ['http://example.org/ns#Node170', 'leoi1683k']
# Path length = 1
# ['http://example.org/ns#Node170', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', '1991-07-07']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', 'ira_913@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', 'male']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', '2004-07-07']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', 'Ira']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node170', 'http://example.org/ns#Node171', '320-486-9691362']
# Path length = 2
# ['http://example.org/ns#Node170', '2000-07-07']
# Path length = 1
# ['http://example.org/ns#Node170', 'The Edgar Allan Poe Awards']
# Path length = 1
# ['http://example.org/ns#Node170', 'http://schema.org/Book']
# Path length = 1
# ['http://example.org/ns#Node170', 'Euripides III: Hecuba / Andromache / The Trojan Women / Ion (Complete Greek Tragedies  #7)']
# Path length = 1
# ['http://example.org/ns#Node170', '500-0-75-79']
# Path length = 1
# ['http://example.org/ns#Node176', '120']
# Path length = 1
# ['http://example.org/ns#Node176', '331-0-66-32']
# Path length = 1
# ['http://example.org/ns#Node176', '1930-07-07']
# Path length = 1
# ['http://example.org/ns#Node176', '1979-07-07']
# Path length = 1
# ['http://example.org/ns#Node176', 'African Literature']
# Path length = 1
# ['http://example.org/ns#Node176', 'en-UK']
# Path length = 1
# ['http://example.org/ns#Node176', 'Graphic Novel']
# Path length = 1
# ['http://example.org/ns#Node176', 'Caldecott Medal']
# Path length = 1
# ['http://example.org/ns#Node176', 'http://schema.org/EBook']
# Path length = 1
# ['http://example.org/ns#Node176', 'The Zanzibar Chest']
# Path length = 1
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', 'Henka']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', '536-684-5043']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', 'henka_454@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', '1940-07-07']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', 'female']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node179', '1979-07-07']
# Path length = 2
# ['http://example.org/ns#Node176', 'Travelogue']
# Path length = 1
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', '761-966-723']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', '1974-07-07']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', 'Collins']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', 'male']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', 'collins_389@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', '1952-07-07']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node177', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', 'male']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', '131-998-890676']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', 'Coleman']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', '2010-07-07']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', 'coleman_570@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', '1989-07-07']
# Path length = 2
# ['http://example.org/ns#Node176', 'http://example.org/ns#Node178', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node176', 'qadr2607ra']
# Path length = 1
# ['http://example.org/ns#Node176', 'http://schema.org/Book']
# Path length = 1
# ['http://example.org/ns#Node121', 'Hugo Award']
# Path length = 1
# ['http://example.org/ns#Node121', '2002-07-07']
# Path length = 1
# ['http://example.org/ns#Node121', 'Religion and Spirituality']
# Path length = 1
# ['http://example.org/ns#Node121', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node121', '1978-07-07']
# Path length = 1
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', '1987-07-07']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', '2017-07-07']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', 'male']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', 'Walter']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', 'walter_344@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node122', '477-034-500']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://schema.org/Hardcover']
# Path length = 1
# ['http://example.org/ns#Node121', 'Cast in Shadow (Chronicles of Elantra  #1)']
# Path length = 1
# ['http://example.org/ns#Node121', 'http://schema.org/Book']
# Path length = 1
# ['http://example.org/ns#Node121', '124']
# Path length = 1
# ['http://example.org/ns#Node121', 'Urban Fantasy']
# Path length = 1
# ['http://example.org/ns#Node121', '161-5-91']
# Path length = 1
# ['http://example.org/ns#Node121', 'en-USA']
# Path length = 1
# ['http://example.org/ns#Node121', 'Nature Writing']
# Path length = 1
# ['http://example.org/ns#Node121', 'ilec8352ods']
# Path length = 1
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', '2003-07-07']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', '1961-07-07']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', 'Aldus']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', 'male']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', 'aldus_377@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node121', 'http://example.org/ns#Node123', '711644-8']
# Path length = 2
# ['http://example.org/ns#Node112', 'Cookbook']
# Path length = 1
# ['http://example.org/ns#Node112', 'National Book Critics Circle Award']
# Path length = 1
# ['http://example.org/ns#Node112', 'Anthropology']
# Path length = 1
# ['http://example.org/ns#Node112', '929-5-14-18561']
# Path length = 1
# ['http://example.org/ns#Node112', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node112', 'Philosophy in a Time of Terror: Dialogues with Jürgen Habermas and Jacques Derrida']
# Path length = 1
# ['http://example.org/ns#Node112', '103']
# Path length = 1
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', 'male']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', '1958-07-07']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', '1992-07-07']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', 'Dustin']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', 'dustin_729@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://example.org/ns#Node113', '347-006-008207']
# Path length = 2
# ['http://example.org/ns#Node112', 'http://schema.org/Hardcover']
# Path length = 1
# ['http://example.org/ns#Node112', 'http://schema.org/Book']
# Path length = 1
# ['http://example.org/ns#Node112', 'Magical Realism']
# Path length = 1
# ['http://example.org/ns#Node112', '1942-07-07']
# Path length = 1
# ['http://example.org/ns#Node112', 'dxdu8891']
# Path length = 1
# ['http://example.org/ns#Node112', 'en-UK']
# Path length = 1
# ['http://example.org/ns#Node112', '1981-07-07']
# Path length = 1
# ['http://example.org/ns#Node158', '2009-07-07']
# Path length = 1
# ['http://example.org/ns#Node158', 'en-USA']
# Path length = 1
# ['http://example.org/ns#Node158', 'The Natural Way to Draw']
# Path length = 1
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', '2008-07-07']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', '1979-07-07']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', 'allyn_450@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', '465353-685044']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', 'Allyn']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', 'female']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node159', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node158', 'Soft Science Fiction']
# Path length = 1
# ['http://example.org/ns#Node158', '136']
# Path length = 1
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', '121-077-4826433']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', 'female']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', 'Fernanda']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', 'fernanda_527@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', '2010-07-07']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', '1989-07-07']
# Path length = 2
# ['http://example.org/ns#Node158', 'http://example.org/ns#Node160', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node158', 'Philosophical Fiction']
# Path length = 1
# ['http://example.org/ns#Node158', "The Women's Prize for Fiction"]
# Path length = 1
# ['http://example.org/ns#Node158', 'http://schema.org/AudiobookFormat']
# Path length = 1
# ['http://example.org/ns#Node158', '1964-07-07']
# Path length = 1
# ['http://example.org/ns#Node158', 'tixc6800aabu36']
# Path length = 1
# ['http://example.org/ns#Node158', 'http://schema.org/Book']
# Path length = 1
# ['http://example.org/ns#Node158', '675-5-25-97719']
# Path length = 1
# ['http://example.org/ns#Node114', '132']
# Path length = 1
# ['http://example.org/ns#Node114', 'Philosophical Fiction']
# Path length = 1
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', '2000-07-07']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', 'witold_237@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', '1952-07-07']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', 'male']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', '852484-408']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node115', 'Witold']
# Path length = 2
# ['http://example.org/ns#Node114', 'Business and Economics']
# Path length = 1
# ['http://example.org/ns#Node114', '1990-07-07']
# Path length = 1
# ['http://example.org/ns#Node114', 'http://schema.org/Book']
# Path length = 1
# ['http://example.org/ns#Node114', 'pjej8114rl']
# Path length = 1
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', '1965-07-07']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', 'Neall']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', 'male']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', '162335-09883012']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', 'neall_374@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node116', '1994-07-07']
# Path length = 2
# ['http://example.org/ns#Node114', 'African American Literature']
# Path length = 1
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', 'http://schema.org/AuthorShape']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', '1952-07-07']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', 'male']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', 'Aron']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', '587-607-8']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', 'aron_458@gmail.com']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', 'http://schema.org/Person']
# Path length = 2
# ['http://example.org/ns#Node114', 'http://example.org/ns#Node117', '1976-07-07']
# Path length = 2
# ['http://example.org/ns#Node114', '944-2-79-511025']
# Path length = 1
# ['http://example.org/ns#Node114', 'Newbery Medal']
# Path length = 1
# ['http://example.org/ns#Node114', 'en-UK']
# Path length = 1
# ['http://example.org/ns#Node114', '1947-07-07']
# Path length = 1
# ['http://example.org/ns#Node114', 'http://schema.org/Paperback']
# Path length = 1
# ['http://example.org/ns#Node114', 'http://schema.org/BookShape']
# Path length = 1
# ['http://example.org/ns#Node114', 'Prodigal Summer']
# Path length = 1
# RESULTS:
# -Number of Paths: 893
# -Absolute depth: 1365
# -Average depth: 1.528555431131019
# -Maximal depth: 2

# %%
# Tangledness 
# source 73 - page 4
# tangledness = mean number of classes with more than 1 direct ancestor, so two primitive 
# measurements (number of classes and number of direct ancestors) are used for computing the metric 

# Select number of classes in graph 
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT (COUNT(DISTINCT ?class) AS ?num_classes)
WHERE {
  {
    # 1. explicitly/implicitly used RDF classes
    # explicitly: ?class a owl:Class . or ?class a rdfs:Class .
    # implicitly: ?any rdf:type ?class . (includes also explicitly used classes)

    # ?any rdf:type ?class .
  }
  UNION
  {
    # 2. subclasses
    # ?class rdfs:subClassOf ?any .
  }
  UNION
  {
    # 3. superclasses
    # ?any rdfs:subClassOf ?class .
  }
  UNION
  {
    # 4. classes used with owl:equivalentClass
    { ?class owl:equivalentClass ?any . }
    UNION
    { ?any owl:equivalentClass ?class . }
  }
  UNION
  {
    # 5. OWL restriction classes
    # ?class a owl:Restriction .
  }
  UNION
  {
    # 6. complex classes with using unionOf, intersectionOf etc.
    # ?class owl:unionOf|owl:intersectionOf|owl:complementOf|owl:oneOf ?list .
  }
  UNION
  {
    # 7. OWL hasValue restrictions
    # ?class owl:hasValue ?val .
  }
}"""

res = g.query(query)
for row in res:
    print("Number of classes in graph: " + str(row['num_classes']))
    num_classes = int(row['num_classes'])

# Select number of classes with more than one ingoing isA arc (Dr. Jovanovik said I should use is-a)
query_var1 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(?class) AS ?tangledCount)
WHERE
{
  SELECT ?class (COUNT(?s) AS ?numIngoing)
  WHERE {
    { ?s rdf:type ?class . }
  }
  GROUP BY ?class
  HAVING (COUNT(?s) > 1) # problem here was: i used ?numIngoing instead of COUNT(?s)
}
"""

# Select number of classes with more than one superclass (source says I should use this query)
query_var2 = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(?class) AS ?tangledCount)
WHERE {
  SELECT ?class (COUNT(?super) AS ?numSupers)
  WHERE {
    # ?class rdfs:subClassOf ?super .
  }
  GROUP BY ?class
  HAVING (COUNT(?super) > 1)
}
"""
res = g.query(query_var2)

t = 0

for row in res:
  print("Number of classes with more than one superclass: " + str(row["tangledCount"]) )
  t = int(row["tangledCount"])
  #print("Class " + str(row["class"]) + ": " + str(row["numIngoing"]))

print("t: " + str(t))

debug_print("\nClasses with more than one superclass: ")

print("\nRESULT:")

if num_classes > 0:
  # source 37 says num_classes / t
  # source 73 says denominator and numerator should be switched -> t / num_classes
  tangledness = t / num_classes
  print("-Tangledness: " + str(tangledness))
else:
  # TODO
   print("-Tangledness is INF")
# Out:
# Number of classes in graph: 2
# Number of classes with more than one superclass: 0
# t: 0
#
# Classes with more than one superclass:
#
# RESULT:
# -Tangledness: 0.0

# %%
# Degree Distribution (Formula in: source 37, page 7)
# nG...number of nodes in gaph
# nE...number of edges in graph

print("STARTING CALCULATING DEGREE DISTRIBUTION")

# Calculating nE
query_nE = """
SELECT (COUNT(*) AS ?tripleCount)
WHERE {
  # ?s ?p ?o .
}
"""

res = g.query(query_nE)
for row in res:
    print("Number of edges in graph: " + str(row['tripleCount']))
    nE = int(row['tripleCount'])

# Calculating nG
query_nG = """
SELECT (COUNT(DISTINCT ?node) AS ?nodeCount)
WHERE {
  {
    SELECT ?node WHERE {
      { ?node ?p1 ?o }       
      UNION
      { ?s ?p2 ?node }       
    }
  }
}
"""

res = g.query(query_nG)

for row in res:
    print("Number of nodes in graph: " + str(row['nodeCount']))
    nG = int(row['nodeCount'])

# Calculating degree for every node in graph
query_degrees = """
SELECT ?node (COUNT(?any) AS ?degree)
WHERE {
  {
    { ?node ?p1 ?any }    
    UNION
    { ?any ?p2 ?node }    
  }
}
GROUP BY ?node
"""

# sum_of_degress = 0
degrees = []

res = g.query(query_degrees)

for row in res:
    #sum_of_degress += int(row['degree'])
    node = row["node"]
    degree = int(row["degree"])
    degrees.append((node, degree))
    debug_print("Node: " + str(node) + " - Degree: " + str(degree))

# Summe aller Degrees
sum_of_degrees = sum(d for _, d in degrees)

print("\nSum of Degrees: " + str(sum_of_degrees))

if nG > 0:
    mean_degree = (2 * nE) / nG
    squared_diffs = [(deg_v - mean_degree) ** 2 for _,deg_v in degrees]
    degree_distribution = sum(squared_diffs) / (nG-1)
else:
    degree_distribution = 0 

print("FINISHED CALCULATING DEGREE DISTRIBUTION")

print("\nRESULT:")
print("-Degree Distribution: " + str(degree_distribution))
# Out:
# STARTING CALCULATING DEGREE DISTRIBUTION
# Number of edges in graph: 952
# Number of nodes in graph: 546
# Node: http://example.org/ns#Node146 - Degree: 14
# Node: http://example.org/ns#Node180 - Degree: 15
# Node: http://example.org/ns#Node142 - Degree: 9
# Node: http://example.org/ns#Node163 - Degree: 9
# Node: http://example.org/ns#Node128 - Degree: 14
# Node: http://example.org/ns#Node185 - Degree: 9
# Node: http://example.org/ns#Node166 - Degree: 9
# Node: http://example.org/ns#Node184 - Degree: 9
# Node: http://example.org/ns#Node121 - Degree: 16
# Node: http://example.org/ns#Node170 - Degree: 14
# Node: http://example.org/ns#Node183 - Degree: 17
# Node: http://example.org/ns#Node117 - Degree: 9
# Node: http://example.org/ns#Node152 - Degree: 9
# Node: http://example.org/ns#Node154 - Degree: 9
# Node: http://example.org/ns#Node104 - Degree: 16
# Node: http://example.org/ns#Node157 - Degree: 9
# Node: http://example.org/ns#Node186 - Degree: 9
# Node: http://example.org/ns#Node167 - Degree: 17
# Node: http://example.org/ns#Node133 - Degree: 9
# Node: http://example.org/ns#Node124 - Degree: 15
# Node: http://example.org/ns#Node160 - Degree: 9
# Node: http://example.org/ns#Node132 - Degree: 17
# Node: http://example.org/ns#Node113 - Degree: 9
# Node: http://example.org/ns#Node173 - Degree: 9
# Node: http://example.org/ns#Node130 - Degree: 16
# Node: http://example.org/ns#Node105 - Degree: 9
# Node: http://example.org/ns#Node134 - Degree: 9
# Node: http://example.org/ns#Node100 - Degree: 17
# Node: http://example.org/ns#Node151 - Degree: 16
# Node: http://example.org/ns#Node125 - Degree: 9
# Node: http://example.org/ns#Node174 - Degree: 9
# Node: http://example.org/ns#Node110 - Degree: 9
# Node: http://example.org/ns#Node145 - Degree: 9
# Node: http://example.org/ns#Node161 - Degree: 17
# Node: http://example.org/ns#Node101 - Degree: 9
# Node: http://example.org/ns#Node140 - Degree: 9
# Node: http://example.org/ns#Node169 - Degree: 9
# Node: http://example.org/ns#Node181 - Degree: 9
# Node: http://example.org/ns#Node162 - Degree: 9
# Node: http://example.org/ns#Node114 - Degree: 17
# Node: http://example.org/ns#Node126 - Degree: 14
# Node: http://example.org/ns#Node139 - Degree: 16
# Node: http://example.org/ns#Node158 - Degree: 15
# Node: http://example.org/ns#Node150 - Degree: 9
# Node: http://example.org/ns#Node176 - Degree: 17
# Node: http://example.org/ns#Node149 - Degree: 9
# Node: http://example.org/ns#Node127 - Degree: 9
# Node: http://example.org/ns#Node153 - Degree: 15
# Node: http://example.org/ns#Node135 - Degree: 17
# Node: Ebert's "Bigger" Little Movie Glossary - Degree: 1
# Node: Catarina - Degree: 1
# Node: Samantha - Degree: 1
# Node: Psychology - Degree: 1
# Node: Witold - Degree: 1
# Node: osbourne_820@gmail.com - Degree: 1
# Node: 109373-27 - Degree: 1
# Node: 211836-771990 - Degree: 1
# Node: 711644-8 - Degree: 1
# Node: 464-9-54-5527 - Degree: 1
# Node: 139 - Degree: 1
# Node: Mythology - Degree: 1
# Node: tixc6800aabu36 - Degree: 1
# Node: 379-092-94 - Degree: 1
# Node: Stig - Degree: 1
# Node: 347-006-008207 - Degree: 1
# Node: Cecilla - Degree: 1
# Node: Science - Degree: 1
# Node: 1947-07-07 - Degree: 1
# Node: 198-706-101165 - Degree: 1
# Node: 1942-07-07 - Degree: 1
# Node: nmqp3699vupo01 - Degree: 1
# Node: Flinx's Folly (Pip & Flinx #9) - Degree: 1
# Node: dxdu8891 - Degree: 1
# Node: walter_344@gmail.com - Degree: 1
# Node: 700-1-02-615615 - Degree: 1
# Node: Instructional and How-To - Degree: 1
# Node: xplj8966sonl67 - Degree: 1
# Node: Space Western - Degree: 1
# Node: Angel - Degree: 1
# Node: 622069-2801572 - Degree: 1
# Node: 125 - Degree: 1
# Node: 2007-07-07 - Degree: 2
# Node: Prodigal Summer - Degree: 1
# Node: 675-5-25-97719 - Degree: 1
# Node: ulrich_696@gmail.com - Degree: 1
# Node: weslie_164@gmail.com - Degree: 1
# Node: 146 - Degree: 1
# Node: 824981-3337894 - Degree: 1
# Node: Magazine and Journal - Degree: 1
# Node: 118 - Degree: 1
# Node: 715-4-25-09 - Degree: 1
# Node: 123 - Degree: 1
# Node: 477-034-500 - Degree: 1
# Node: Family Saga - Degree: 1
# Node: The Sea of Monsters (Percy Jackson and the Olympians  #2) - Degree: 1
# Node: 320-486-9691362 - Degree: 1
# Node: Historical Non-Fiction - Degree: 1
# Node: Legend of the Five Rings RPG - Degree: 1
#
# Sum of Degrees: 1904
# FINISHED CALCULATING DEGREE DISTRIBUTION
#
# RESULT:
# -Degree Distribution: 33.398917901670195

# %%
print("STARTING CALCULATING ENTITIES/CLASSES/PROPERTIES/...")

# TODO: Entities

# Number of instances per type
query_inst = """ SELECT ?type (COUNT(?s) AS ?count)
WHERE {
  # ?s rdf:type ?type . 
}
GROUP BY ?type """

res = g.query(query_inst)

num_instances = 0

for row in res:
    rdf_type = row["type"]
    count = int(row["count"])
    debug_print("Number of instancees of" + rdf_type + ": " + str(count))
    num_instances += count

# Number of classes
# Defintion of Class: 
# source: 213, page: 5 - source: 250, page: 3
# TNOC (total number of classes/concepts) = classes, subclasses, superclasses, anonymous classes
# anonymous classes = equivalent/restriction/unionOf/intersectionOf/complementOf/oneOf/hasValue classes

query_classes = """ 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?class
WHERE {
  {
    # 1. explicitly/implicitly used RDF classes
    # explicitly: ?class a owl:Class . or ?class a rdfs:Class .
    # implicitly: ?any rdf:type ?class . (includes also explicitly used classes)

    # ?any rdf:type ?class .
  }
  UNION
  {
    # 2. subclasses
    # ?class rdfs:subClassOf ?any .
  }
  UNION
  {
    # 3. superclasses
    # ?any rdfs:subClassOf ?class .
  }
  UNION
  {
    # 4. classes used with owl:equivalentClass
    { ?class owl:equivalentClass ?any . }
    UNION
    { ?any owl:equivalentClass ?class . }
  }
  UNION
  {
    # 5. OWL restriction classes
    # ?class a owl:Restriction .
  }
  UNION
  {
    # 6. complex classes with using unionOf, intersectionOf etc.
    # ?class owl:unionOf|owl:intersectionOf|owl:complementOf|owl:oneOf ?list .
  }
  UNION
  {
    # 7. OWL hasValue restrictions
    # ?class owl:hasValue ?val .
  }
}
"""
res = g.query(query_classes)

num_classes = 0

debug_print("\nExisting classes: ")

for row in res:
  num_classes += 1
  debug_print("Class " + str(num_classes) + ": " + str(row["class"]))

# number of properties in T-Box
query_properties = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(DISTINCT ?property) AS ?NoP)
WHERE {
  VALUES ?type { owl:ObjectProperty owl:DatatypeProperty owl:AnnotationProperty }
  # ?property rdf:type ?type .
}
"""

res = g.query(query_properties)

num_properties = 0

for row in res:
  num_properties = int(row["NoP"])

# Number of object properties
# Non-Inheritance -> excluding inheritance properties like rdfs:subPropertyOf or rdfs:subClassOf
query_object_properties = """
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT (COUNT(DISTINCT ?property) AS ?numObjectProperties)
WHERE {
  # ?property rdf:type owl:ObjectProperty .
}
"""

res = g.query(query_object_properties)

num_obj_properties = 0

for row in res:
  num_obj_properties = int(row["numObjectProperties"])

print("\nRESULTS:")
print("-Number of properties: " + str(num_properties))
print("-Number of classes: " + str(num_classes))
print("-Number of instances: " + str(num_instances))
print("-Number of object properties: " + str(num_obj_properties))
# Out:
# Number of instancees ofhttp://schema.org/Book does not look like a valid URI, trying to serialize this will break.
# Number of instancees ofhttp://schema.org/Book:  does not look like a valid URI, trying to serialize this will break.
# Number of instancees ofhttp://schema.org/Book: 30 does not look like a valid URI, trying to serialize this will break.
# Number of instancees ofhttp://schema.org/Person does not look like a valid URI, trying to serialize this will break.
# Number of instancees ofhttp://schema.org/Person:  does not look like a valid URI, trying to serialize this will break.
# Number of instancees ofhttp://schema.org/Person: 59 does not look like a valid URI, trying to serialize this will break.
# STARTING CALCULATING ENTITIES/CLASSES/PROPERTIES/...
# Number of instancees ofhttp://schema.org/Book: 30
# Number of instancees ofhttp://schema.org/Person: 59
#
# Existing classes:
# Class 1: http://schema.org/Book
# Class 2: http://schema.org/Person
#
# RESULTS:
# -Number of properties: 0
# -Number of classes: 2
# -Number of instances: 89
# -Number of object properties: 0

# %%
# TODO: Depth of Inheritance Tree

# %%
# Property Class Ratio
if num_classes > 0:
    prop_class_ratio = num_properties / num_classes 
    print("Property Class Ratio: " + str(prop_class_ratio))
else:
    # TODO
    print("Property Class Ratio is INF!")

# Class Property Ratio
if num_properties > 0:
    class_prop_ratio = num_classes / num_properties 
    print("Class Property Ratio: " + str(class_prop_ratio))
else:
    # TODO
    print("Class Property Ratio is INF!")

# Inheritance Richness = average number of subclasses per clas (source 227 - page 9) 
query_subclasses = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(*) AS ?numInheritanceRelations)
WHERE {
  # ?subclass rdfs:subClassOf ?superclass .
}
"""

num_subclasses = 0

res = g.query(query_subclasses)

for row in res:
  num_subclasses = int(row["numInheritanceRelations"])

if num_classes > 0:
    inheritance_richness = num_subclasses / num_classes 
    print("Inheritance Richness: " + str(inheritance_richness))
else:
    # TODO
    print("Inheritance Richness is INF!")

query_datatype_properties = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT (COUNT(DISTINCT ?property) AS ?numDatatypeProperties)
WHERE {
  # ?property rdf:type owl:DatatypeProperty .
}
"""

num_datatype_properties = 0

res = g.query(query_datatype_properties)

for row in res:
  num_datatype_properties = int(row["numDatatypeProperties"])

debug_print("Number of Datatype properties: " + str(num_datatype_properties))

if num_classes > 0:
    attr_richness = num_datatype_properties / num_classes
    print("Attribute Richness: " + str(attr_richness))
else:
    print("Attribute Richness is INF!")
# Out:
# Property Class Ratio: 0.0
# Class Property Ratio is INF!
# Inheritance Richness: 0.0
# Number of Datatype properties: 0
# Attribute Richness: 0.0

# %%
# Average Connectivity
if num_classes > 0:
    avg_population = num_instances / num_classes
    print("Average Population: " + str(avg_population))
else:
    print("Average Population is INF!")
# Out:
# Average Population: 44.5

# %%
# TODO: Cohesion

# %%
# Average Class Connectivity
# Connectivity of a class is defined as the total number of relationships instances of 
# the class have with instances of other classes (source 227 - page 10)

# looking for number of triples (c1, p, c2) or (c3, p, c1) for each class with instances c1
# c1, c2 are instances of classes 
# c1 != c2
# property != rdf:type because we are not interested in the class relationships 
query_class_connectivity = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT ?class (COUNT(*) AS ?connectivity)
WHERE {
  {
    # ?instance ?property ?target .

    # ?instance rdf:type ?class .
    # ?target rdf:type ?targetClass .

    FILTER(?property != rdf:type)
    FILTER(?class != ?targetClass)
  }
  UNION
  {
    # ?instance ?property ?target .

    # ?target rdf:type ?class .
    # ?instance rdf:type ?targetClass .

    FILTER(?property != rdf:type)
    FILTER(?class != ?targetClass)
  }
}
GROUP BY ?class
"""

class_connectivity_list = []
sum_connectivities = 0

res = g.query(query_class_connectivity)

for row in res:
    class_name = row["class"]
    connectivity = int(row["connectivity"])
    class_connectivity_list.append((class_name, connectivity))
    sum_connectivities += connectivity


for class_name, connectivity in class_connectivity_list:
  debug_print("Connectivity of Class " + str(class_name) + ": " + str(connectivity))

if num_classes > 0:
  avg_class_connectivity = sum_connectivities / num_classes
  print("Average Class Connectivity: " + str(avg_class_connectivity))
else:
  print("Average Class Connectivity is INF!")
# Out:
# Connectivity of Class http://schema.org/Book does not look like a valid URI, trying to serialize this will break.
# Connectivity of Class http://schema.org/Book:  does not look like a valid URI, trying to serialize this will break.
# Connectivity of Class http://schema.org/Book: 59 does not look like a valid URI, trying to serialize this will break.
# Connectivity of Class http://schema.org/Person does not look like a valid URI, trying to serialize this will break.
# Connectivity of Class http://schema.org/Person:  does not look like a valid URI, trying to serialize this will break.
# Connectivity of Class http://schema.org/Person: 59 does not look like a valid URI, trying to serialize this will break.
# Connectivity of Class http://schema.org/Book: 59
# Connectivity of Class http://schema.org/Person: 59
# Average Class Connectivity: 59.0
